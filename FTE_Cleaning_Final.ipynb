# %%
import pandas as pd

# %% [markdown]
# ## Reading dataset and check the info

# %%
df = pd.read_csv("../../dataset/All/22232-FTE.csv")

# %%
df
# Out:
#                  id                                 eventname     component  \
# 0         822240952                 \core\event\course_viewed          core
# 1         822241112      \mod_quiz\event\course_module_viewed      mod_quiz
# 2         822241314           \mod_quiz\event\attempt_started      mod_quiz
# 3         822241316            \mod_quiz\event\attempt_viewed      mod_quiz
# 4         822244944    \mod_quiz\event\attempt_summary_viewed      mod_quiz
# ...             ...                                       ...           ...
# 7716635   889073977                 \core\event\course_viewed          core
# 7716636  1036456258                 \core\event\course_viewed          core
# 7716637  1036456259  \mod_resource\event\course_module_viewed  mod_resource
# 7716638  1036456261  \mod_resource\event\course_module_viewed  mod_resource
# 7716639  1036456462  \mod_resource\event\course_module_viewed  mod_resource
#
#           action           target    objecttable   objectid crud  edulevel  \
# 0         viewed           course            NaN        NaN    r         2
# 1         viewed    course_module           quiz   325325.0    r         2
# 2        started          attempt  quiz_attempts  6540853.0    c         2
# 3         viewed          attempt  quiz_attempts  6540853.0    r         2
# 4         viewed  attempt_summary  quiz_attempts  6540853.0    r         1
# ...          ...              ...            ...        ...  ...       ...
# 7716635   viewed           course            NaN        NaN    r         2
# 7716636   viewed           course            NaN        NaN    r         2
# 7716637   viewed    course_module       resource   495664.0    r         2
# 7716638   viewed    course_module       resource   495665.0    r         2
# 7716639   viewed    course_module       resource   495666.0    r         2
#
#          contextid  ...  contextinstanceid  userid  courseid  relateduserid  \
# 0          3670909  ...              30453   70858     30453            NaN
# 1          3671032  ...            2758641   70858     30453            NaN
# 2          3671032  ...            2758641   70858     30453        70858.0
# 3          3671032  ...            2758641   70858     30453        70858.0
# 4          3671032  ...            2758641   70858     30453        70858.0
# ...            ...  ...                ...     ...       ...            ...
# 7716635    3888375  ...              33549   23979     33549            NaN
# 7716636    3888375  ...              33549   23979     33549            NaN
# 7716637    3888377  ...            2972804   23979     33549            NaN
# 7716638    3888381  ...            2972808   23979     33549            NaN
# 7716639    3888384  ...            2972811   23979     33549            NaN
#
#          anonymous                             other timecreated  origin  \
# 0                0                                N;  1679561358     web
# 1                0                                N;  1679561375     web
# 2                0                                N;  1679561399     web
# 3                0  a:1:{s:6:"quizid";s:6:"325325";}  1679561399     web
# 4                0  a:1:{s:6:"quizid";s:6:"325325";}  1679561747     web
# ...            ...                               ...         ...     ...
# 7716635          0                                N;  1687787732     web
# 7716636          0                                N;  1707864550     web
# 7716637          0                                N;  1707864557     web
# 7716638          0                                N;  1707864584     web
# 7716639          0                                N;  1707864611     web
#
#                       ip realuserid
# 0        114.122.106.213        NaN
# 1        114.122.106.213        NaN
# 2        114.122.106.213        NaN
# 3        114.122.106.213        NaN
# 4        114.122.106.213        NaN
# ...                  ...        ...
# 7716635     36.85.228.40        NaN
# 7716636   180.244.134.80        NaN
# 7716637   180.244.134.80        NaN
# 7716638   180.244.134.80        NaN
# 7716639   180.244.134.80        NaN
#
# [7716640 rows x 21 columns]

# %%
df.shape
# Out:
# (7716640, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7716640 entries, 0 to 7716639
# Data columns (total 21 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   id                 int64
#  1   eventname          object
#  2   component          object
#  3   action             object
#  4   target             object
#  5   objecttable        object
#  6   objectid           float64
#  7   crud               object
#  8   edulevel           int64
#  9   contextid          int64
#  10  contextlevel       int64
#  11  contextinstanceid  int64
#  12  userid             int64
#  13  courseid           int64
#  14  relateduserid      float64
#  15  anonymous          int64
#  16  other              object
#  17  timecreated        int64
#  18  origin             object
#  19  ip                 object
#  20  realuserid         float64
# dtypes: float64(3), int64(9), object(9)
# memory usage: 1.2+ GB

# %% [markdown]
# ## Count unique values in each column

# %%
for col in df.columns:
    n = len(pd.unique(df[col]))
    print("{:<20}: {:<}".format(col, n))
# Out:
# id                  : 7716297
# eventname           : 167
# component           : 38
# action              : 27
# target              : 71
# objecttable         : 56
# objectid            : 1058027
# crud                : 4
# edulevel            : 3
# contextid           : 51927
# contextlevel        : 2
# contextinstanceid   : 51927
# userid              : 3699
# courseid            : 676
# relateduserid       : 3659
# anonymous           : 2
# other               : 446959
# timecreated         : 3130092
# origin              : 4
# ip                  : 61538
# realuserid          : 1

# %% [markdown]
# ## Check if there is null values

# %%
df.isnull().sum()
# Out:
# id                         0
# eventname                  0
# component                  0
# action                     0
# target                     0
# objecttable          1813625
# objectid             1813625
# crud                       0
# edulevel                   0
# contextid                  0
# contextlevel               0
# contextinstanceid          0
# userid                     0
# courseid                   0
# relateduserid        3936738
# anonymous                  0
# other                      0
# timecreated                0
# origin                     0
# ip                     60077
# realuserid           7716640
# dtype: int64

# %% [markdown]
# ## Change time from epoch to datetime

# %% [markdown]
# ### Convert the time to datetime

# %%
df['timecreated'] = pd.to_datetime(df['timecreated'], unit='s')
df
# Out:
#                  id                                 eventname     component  \
# 0         822240952                 \core\event\course_viewed          core
# 1         822241112      \mod_quiz\event\course_module_viewed      mod_quiz
# 2         822241314           \mod_quiz\event\attempt_started      mod_quiz
# 3         822241316            \mod_quiz\event\attempt_viewed      mod_quiz
# 4         822244944    \mod_quiz\event\attempt_summary_viewed      mod_quiz
# ...             ...                                       ...           ...
# 7716635   889073977                 \core\event\course_viewed          core
# 7716636  1036456258                 \core\event\course_viewed          core
# 7716637  1036456259  \mod_resource\event\course_module_viewed  mod_resource
# 7716638  1036456261  \mod_resource\event\course_module_viewed  mod_resource
# 7716639  1036456462  \mod_resource\event\course_module_viewed  mod_resource
#
#           action           target    objecttable   objectid crud  edulevel  \
# 0         viewed           course            NaN        NaN    r         2
# 1         viewed    course_module           quiz   325325.0    r         2
# 2        started          attempt  quiz_attempts  6540853.0    c         2
# 3         viewed          attempt  quiz_attempts  6540853.0    r         2
# 4         viewed  attempt_summary  quiz_attempts  6540853.0    r         1
# ...          ...              ...            ...        ...  ...       ...
# 7716635   viewed           course            NaN        NaN    r         2
# 7716636   viewed           course            NaN        NaN    r         2
# 7716637   viewed    course_module       resource   495664.0    r         2
# 7716638   viewed    course_module       resource   495665.0    r         2
# 7716639   viewed    course_module       resource   495666.0    r         2
#
#          contextid  ...  contextinstanceid  userid  courseid  relateduserid  \
# 0          3670909  ...              30453   70858     30453            NaN
# 1          3671032  ...            2758641   70858     30453            NaN
# 2          3671032  ...            2758641   70858     30453        70858.0
# 3          3671032  ...            2758641   70858     30453        70858.0
# 4          3671032  ...            2758641   70858     30453        70858.0
# ...            ...  ...                ...     ...       ...            ...
# 7716635    3888375  ...              33549   23979     33549            NaN
# 7716636    3888375  ...              33549   23979     33549            NaN
# 7716637    3888377  ...            2972804   23979     33549            NaN
# 7716638    3888381  ...            2972808   23979     33549            NaN
# 7716639    3888384  ...            2972811   23979     33549            NaN
#
#          anonymous                             other         timecreated  \
# 0                0                                N; 2023-03-23 08:49:18
# 1                0                                N; 2023-03-23 08:49:35
# 2                0                                N; 2023-03-23 08:49:59
# 3                0  a:1:{s:6:"quizid";s:6:"325325";} 2023-03-23 08:49:59
# 4                0  a:1:{s:6:"quizid";s:6:"325325";} 2023-03-23 08:55:47
# ...            ...                               ...                 ...
# 7716635          0                                N; 2023-06-26 13:55:32
# 7716636          0                                N; 2024-02-13 22:49:10
# 7716637          0                                N; 2024-02-13 22:49:17
# 7716638          0                                N; 2024-02-13 22:49:44
# 7716639          0                                N; 2024-02-13 22:50:11
#
#         origin               ip realuserid
# 0          web  114.122.106.213        NaN
# 1          web  114.122.106.213        NaN
# 2          web  114.122.106.213        NaN
# 3          web  114.122.106.213        NaN
# 4          web  114.122.106.213        NaN
# ...        ...              ...        ...
# 7716635    web     36.85.228.40        NaN
# 7716636    web   180.244.134.80        NaN
# 7716637    web   180.244.134.80        NaN
# 7716638    web   180.244.134.80        NaN
# 7716639    web   180.244.134.80        NaN
#
# [7716640 rows x 21 columns]

# %% [markdown]
# ### Check the range of the dataset

# %%
# Find the minimum and maximum dates
min_date = df['timecreated'].min()
max_date = df['timecreated'].max()

print('Minimum date:', min_date)
print('Maximum date:', max_date)
# Out:
# Minimum date: 2023-03-23 07:46:19
# Maximum date: 2024-03-21 06:24:18

# %% [markdown]
# ## Remove uneccessary columns

# %%
df = df.drop(columns = ['objecttable', 'objectid', 'contextid', 
                         'contextlevel', 'contextinstanceid', 'relateduserid',
                         'anonymous', 'other', 'origin', 'ip', 'realuserid'])
df
# Out:
#                  id                                 eventname     component  \
# 0         822240952                 \core\event\course_viewed          core
# 1         822241112      \mod_quiz\event\course_module_viewed      mod_quiz
# 2         822241314           \mod_quiz\event\attempt_started      mod_quiz
# 3         822241316            \mod_quiz\event\attempt_viewed      mod_quiz
# 4         822244944    \mod_quiz\event\attempt_summary_viewed      mod_quiz
# ...             ...                                       ...           ...
# 7716635   889073977                 \core\event\course_viewed          core
# 7716636  1036456258                 \core\event\course_viewed          core
# 7716637  1036456259  \mod_resource\event\course_module_viewed  mod_resource
# 7716638  1036456261  \mod_resource\event\course_module_viewed  mod_resource
# 7716639  1036456462  \mod_resource\event\course_module_viewed  mod_resource
#
#           action           target crud  edulevel  userid  courseid  \
# 0         viewed           course    r         2   70858     30453
# 1         viewed    course_module    r         2   70858     30453
# 2        started          attempt    c         2   70858     30453
# 3         viewed          attempt    r         2   70858     30453
# 4         viewed  attempt_summary    r         1   70858     30453
# ...          ...              ...  ...       ...     ...       ...
# 7716635   viewed           course    r         2   23979     33549
# 7716636   viewed           course    r         2   23979     33549
# 7716637   viewed    course_module    r         2   23979     33549
# 7716638   viewed    course_module    r         2   23979     33549
# 7716639   viewed    course_module    r         2   23979     33549
#
#                 timecreated
# 0       2023-03-23 08:49:18
# 1       2023-03-23 08:49:35
# 2       2023-03-23 08:49:59
# 3       2023-03-23 08:49:59
# 4       2023-03-23 08:55:47
# ...                     ...
# 7716635 2023-06-26 13:55:32
# 7716636 2024-02-13 22:49:10
# 7716637 2024-02-13 22:49:17
# 7716638 2024-02-13 22:49:44
# 7716639 2024-02-13 22:50:11
#
# [7716640 rows x 10 columns]

# %%
df.isnull().sum()
# Out:
# id             0
# eventname      0
# component      0
# action         0
# target         0
# crud           0
# edulevel       0
# userid         0
# courseid       0
# timecreated    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7716640 entries, 0 to 7716639
# Data columns (total 10 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   id           int64
#  1   eventname    object
#  2   component    object
#  3   action       object
#  4   target       object
#  5   crud         object
#  6   edulevel     int64
#  7   userid       int64
#  8   courseid     int64
#  9   timecreated  datetime64[ns]
# dtypes: datetime64[ns](1), int64(4), object(5)
# memory usage: 588.7+ MB

# %% [markdown]
# ## Check if there is duplicates data and remove it

# %% [markdown]
# ### Check for duplicates

# %%
duplicate_mask = df.duplicated(keep=False)

duplicate_rows = df[duplicate_mask]
duplicate_rows
# Out:
#                 id                           eventname component      action  \
# 4843978  857498182           \core\event\course_viewed      core      viewed
# 4843979  857498182           \core\event\course_viewed      core      viewed
# 4843980  857498308        \core\event\user_list_viewed      core      viewed
# 4843981  857498308        \core\event\user_list_viewed      core      viewed
# 4843982  857498652         \core\event\role_unassigned      core  unassigned
# ...            ...                                 ...       ...         ...
# 5549701  857501064        \core\event\user_list_viewed      core      viewed
# 5549702  857501397         \core\event\role_unassigned      core  unassigned
# 5549703  857501397         \core\event\role_unassigned      core  unassigned
# 5549704  857501398  \core\event\user_enrolment_deleted      core     deleted
# 5549705  857501398  \core\event\user_enrolment_deleted      core     deleted
#
#                  target crud  edulevel  userid  courseid         timecreated
# 4843978          course    r         2   36906     30816 2023-05-15 06:19:38
# 4843979          course    r         2   36906     30816 2023-05-15 06:19:38
# 4843980       user_list    r         0   36906     30816 2023-05-15 06:19:52
# 4843981       user_list    r         0   36906     30816 2023-05-15 06:19:52
# 4843982            role    d         0   36906     30816 2023-05-15 06:20:18
# ...                 ...  ...       ...     ...       ...                 ...
# 5549701       user_list    r         0   36906     31826 2023-05-15 06:23:18
# 5549702            role    d         0   36906     31826 2023-05-15 06:23:44
# 5549703            role    d         0   36906     31826 2023-05-15 06:23:44
# 5549704  user_enrolment    d         0   36906     31826 2023-05-15 06:23:44
# 5549705  user_enrolment    d         0   36906     31826 2023-05-15 06:23:44
#
# [686 rows x 10 columns]

# %% [markdown]
# ### Drop duplicates

# %%
df.drop_duplicates()
# Out:
#                  id                                 eventname     component  \
# 0         822240952                 \core\event\course_viewed          core
# 1         822241112      \mod_quiz\event\course_module_viewed      mod_quiz
# 2         822241314           \mod_quiz\event\attempt_started      mod_quiz
# 3         822241316            \mod_quiz\event\attempt_viewed      mod_quiz
# 4         822244944    \mod_quiz\event\attempt_summary_viewed      mod_quiz
# ...             ...                                       ...           ...
# 7716635   889073977                 \core\event\course_viewed          core
# 7716636  1036456258                 \core\event\course_viewed          core
# 7716637  1036456259  \mod_resource\event\course_module_viewed  mod_resource
# 7716638  1036456261  \mod_resource\event\course_module_viewed  mod_resource
# 7716639  1036456462  \mod_resource\event\course_module_viewed  mod_resource
#
#           action           target crud  edulevel  userid  courseid  \
# 0         viewed           course    r         2   70858     30453
# 1         viewed    course_module    r         2   70858     30453
# 2        started          attempt    c         2   70858     30453
# 3         viewed          attempt    r         2   70858     30453
# 4         viewed  attempt_summary    r         1   70858     30453
# ...          ...              ...  ...       ...     ...       ...
# 7716635   viewed           course    r         2   23979     33549
# 7716636   viewed           course    r         2   23979     33549
# 7716637   viewed    course_module    r         2   23979     33549
# 7716638   viewed    course_module    r         2   23979     33549
# 7716639   viewed    course_module    r         2   23979     33549
#
#                 timecreated
# 0       2023-03-23 08:49:18
# 1       2023-03-23 08:49:35
# 2       2023-03-23 08:49:59
# 3       2023-03-23 08:49:59
# 4       2023-03-23 08:55:47
# ...                     ...
# 7716635 2023-06-26 13:55:32
# 7716636 2024-02-13 22:49:10
# 7716637 2024-02-13 22:49:17
# 7716638 2024-02-13 22:49:44
# 7716639 2024-02-13 22:50:11
#
# [7716297 rows x 10 columns]

# %% [markdown]
# ## Shortened the event name

# %%
shortened = list(value.split('\\')[1] + "\\" +  value.split('\\')[-1] for value in df["eventname"])
df["event"] = shortened
df
# Out:
#                  id                                 eventname     component  \
# 0         822240952                 \core\event\course_viewed          core
# 1         822241112      \mod_quiz\event\course_module_viewed      mod_quiz
# 2         822241314           \mod_quiz\event\attempt_started      mod_quiz
# 3         822241316            \mod_quiz\event\attempt_viewed      mod_quiz
# 4         822244944    \mod_quiz\event\attempt_summary_viewed      mod_quiz
# ...             ...                                       ...           ...
# 7716635   889073977                 \core\event\course_viewed          core
# 7716636  1036456258                 \core\event\course_viewed          core
# 7716637  1036456259  \mod_resource\event\course_module_viewed  mod_resource
# 7716638  1036456261  \mod_resource\event\course_module_viewed  mod_resource
# 7716639  1036456462  \mod_resource\event\course_module_viewed  mod_resource
#
#           action           target crud  edulevel  userid  courseid  \
# 0         viewed           course    r         2   70858     30453
# 1         viewed    course_module    r         2   70858     30453
# 2        started          attempt    c         2   70858     30453
# 3         viewed          attempt    r         2   70858     30453
# 4         viewed  attempt_summary    r         1   70858     30453
# ...          ...              ...  ...       ...     ...       ...
# 7716635   viewed           course    r         2   23979     33549
# 7716636   viewed           course    r         2   23979     33549
# 7716637   viewed    course_module    r         2   23979     33549
# 7716638   viewed    course_module    r         2   23979     33549
# 7716639   viewed    course_module    r         2   23979     33549
#
#                 timecreated                              event
# 0       2023-03-23 08:49:18                 core\course_viewed
# 1       2023-03-23 08:49:35      mod_quiz\course_module_viewed
# 2       2023-03-23 08:49:59           mod_quiz\attempt_started
# 3       2023-03-23 08:49:59            mod_quiz\attempt_viewed
# 4       2023-03-23 08:55:47    mod_quiz\attempt_summary_viewed
# ...                     ...                                ...
# 7716635 2023-06-26 13:55:32                 core\course_viewed
# 7716636 2024-02-13 22:49:10                 core\course_viewed
# 7716637 2024-02-13 22:49:17  mod_resource\course_module_viewed
# 7716638 2024-02-13 22:49:44  mod_resource\course_module_viewed
# 7716639 2024-02-13 22:50:11  mod_resource\course_module_viewed
#
# [7716640 rows x 11 columns]

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ### Distribution of Events Over Time

# %%
events_by_day = df.groupby(df['timecreated'].dt.date).size()

# %%
# PLot the distribution of events over time
plt.figure(figsize=(10, 6))
events_by_day.plot(kind='line', marker='o', color='b')
plt.title('Distribution of Events Over Time')
plt.xlabel('Date')
plt.ylabel('Number of Events')
plt.grid(True)
plt.xticks(rotation=45) # Rotate x-axis labels for better readability
plt.tight_layout()
plt.show()

# %%
# Filter data between two dates
filtered_df = df.loc[(df['timecreated'] < '2023-06-26')]

# %%
filtered_events_by_day = filtered_df.groupby(filtered_df['timecreated'].dt.date).size()

# %%
# PLot the distribution of events over time
plt.figure(figsize=(10, 6))
filtered_events_by_day.plot(kind='line', marker='o', color='b')
plt.title('Distribution of Events Over Time')
plt.xlabel('Date')
plt.ylabel('Number of Events')
plt.grid(True)
plt.xticks(rotation=45) # Rotate x-axis labels for better readability
plt.tight_layout()
plt.show()

# %%
# Group events by educational level and calculate the frequency of events for each level
events_by_edulevel = filtered_df.groupby('edulevel').size()

# %%
# Plot the distribution of events across different educational levels
plt.figure(figsize=(10, 6))
events_by_edulevel.plot(kind='bar', color='salmon')
plt.title('Distribution of Events Across Educational Levels')
plt.xlabel('Educational Level')
plt.ylabel('Frequency of Events')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Admin EDA

# %%
# Select the admin data
admin_df = filtered_df[filtered_df['edulevel'] == 0]
# admin_df

# %% [markdown]
# ### Count how many unique values in each column

# %%
for col in admin_df.columns:
    n = len(pd.unique(admin_df[col]))
    print("{:<20}: {:<}".format(col, n))
# Out:
# id                  : 990234
# eventname           : 38
# component           : 8
# action              : 9
# target              : 24
# crud                : 4
# edulevel            : 1
# userid              : 3608
# courseid            : 648
# timecreated         : 729388
# event               : 35

# %% [markdown]
# ### Events over time

# %%
admin_events_by_day = admin_df.groupby(admin_df['timecreated'].dt.date).size()

# %%
# Calculate the average number of events per day
average_events_per_day = admin_events_by_day.mean()

# PLot the distribution of events over time
plt.figure(figsize=(10, 6))
admin_events_by_day.plot(kind='line', marker='o', color='b')
plt.axhline(y=average_events_per_day, color='r', linestyle='--', label='Average Events per Day') # Add the average line
plt.title('Distribution of Events Over Time')
plt.xlabel('Date')
plt.ylabel('Number of Events')
plt.grid(True)
plt.xticks(rotation=45) # Rotate x-axis labels for better readability
plt.legend() # Show legend
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Top 5 and bottom 5 of event frequencies

# %%
event_counts = admin_df['event'].value_counts()

admin_top5_events = event_counts.head(5)
admin_bottom5_events = event_counts.tail(5)

# %%
admin_combined_events = pd.concat([admin_top5_events, admin_bottom5_events])

# %%
plt.figure(figsize=(12, 6))
bars = admin_combined_events.plot(kind='bar', color=['skyblue']*5 + ['salmon']*5)
plt.title('Top 5 and Bottom 5 Events by Frequency (Admin)')
plt.xlabel('Events')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.tight_layout()

for i, v in enumerate(admin_combined_events):
    bars.text(i, v + 0.2, str(v), ha='center', va='bottom')
    
plt.show()

# %% [markdown]
# ### Top 5 and bottom 5 action

# %%
action_counts = admin_df['action'].value_counts()

admin_top5_actions = action_counts.head(5)
admin_bot5_actions = action_counts.tail(4)

# %%
admin_combined_actions = pd.concat([admin_top5_actions, admin_bot5_actions])

# %%
plt.figure(figsize=(12, 6))
bars = admin_combined_actions.plot(kind='bar', color=['skyblue']*5 + ['salmon']*5)
plt.title('Actions by Frequency (Admin)')
plt.xlabel('Actions')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.tight_layout()

for i, v in enumerate(admin_combined_actions):
    bars.text(i, v + 0.2, str(v), ha='center', va='bottom')

plt.show()

# %% [markdown]
# ### Top 5 and bottom 5 of components

# %%
component_counts = admin_df['component'].value_counts()

admin_top5_components = component_counts.head(4)
admin_bot5_components = component_counts.tail(3)

# %%
admin_combined_components = pd.concat([admin_top5_components, admin_bot5_components])

# %%
plt.figure(figsize=(12,6))
bars = admin_combined_components.plot(kind='bar', color=['skyblue']*5 + ['salmon']*5)
plt.title('Components by Frequency (Admin)')
plt.xlabel('Components')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.tight_layout()

for i, v in enumerate(admin_combined_components):
    bars.text(i, v + 0.2, str(v), ha='center', va='bottom')

plt.show()

# %% [markdown]
# ## Lecturer EDA

# %%
# Select the lecturer data
lecturer_df = filtered_df[filtered_df['edulevel'] == 1]
# lecturer_df

# %% [markdown]
# ### Count how many unique values in each column

# %%
for col in lecturer_df.columns:
    n = len(pd.unique(lecturer_df[col]))
    print("{:<20}: {:<}".format(col, n))
# Out:
# id                  : 613634
# eventname           : 62
# component           : 14
# action              : 16
# target              : 29
# crud                : 4
# edulevel            : 1
# userid              : 3396
# courseid            : 605
# timecreated         : 400933
# event               : 62

# %% [markdown]
# ### Events over time

# %%
lecturer_events_by_day = lecturer_df.groupby(lecturer_df['timecreated'].dt.date).size()

# %%
# Calculate the average number of events per day
average_events_per_day = lecturer_events_by_day.mean()

# PLot the distribution of events over time
plt.figure(figsize=(10, 6))
lecturer_events_by_day.plot(kind='line', marker='o', color='b')
plt.axhline(y=average_events_per_day, color='r', linestyle='--', label='Average Events per Day') # Add the average line
plt.title('Distribution of Events Over Time')
plt.xlabel('Date')
plt.ylabel('Number of Events')
plt.grid(True)
plt.xticks(rotation=45) # Rotate x-axis labels for better readability
plt.legend() # Show legend
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Top 5 and bottom 5 of event frequencies

# %%
event_counts = lecturer_df['event'].value_counts()

lecturer_top5_events = event_counts.head(5)
lecturer_bottom5_events = event_counts.tail(5)

# %%
lecturer_combined_events = pd.concat([lecturer_top5_events, lecturer_bottom5_events])

# %%
plt.figure(figsize=(12, 6))
bars = lecturer_combined_events.plot(kind='bar', color=['skyblue']*5 + ['salmon']*5)
plt.title('Top 5 and Bottom 5 Events by frequency (Lecturer)')
plt.xlabel('Events')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.tight_layout()

for i, v in enumerate(lecturer_combined_events):
    bars.text(i, v + 0.2, str(v), ha='center', va='bottom')

plt.show()

# %%
plt.figure(figsize=(12, 6))
bars = lecturer_combined_events.plot(kind='bar', color=['skyblue']*5 + ['salmon']*5)
plt.title('Top 5 and Bottom 5 Events by frequency (Lecturer)')
plt.xlabel('Events')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.tight_layout()

for i, v in enumerate(lecturer_combined_events):
    bars.text(i, v + 0.2, str(v), ha='center', va='bottom')

plt.show()

# %%
# Get the top 5 events
event_counts = lecturer_df['event'].value_counts()
lecturer_top5_events = event_counts.head(5).index

# Filter the dataframe to include only the top 5 events
top5_df = lecturer_df[lecturer_df['event'].isin(lecturer_top5_events)]

# Convert 'timecreated' to datetime if it's not already
top5_df['timecreated'] = pd.to_datetime(top5_df['timecreated'])

# Extract the date from 'timecreated'
top5_df['date'] = top5_df['timecreated'].dt.date

# Group by 'event' and 'date' and count occurrences
event_by_day = top5_df.groupby(['date', 'event']).size().unstack(fill_value=0)

# Plot the data
plt.figure(figsize=(12, 8))
for event in lecturer_top5_events:
    plt.plot(event_by_day.index, event_by_day[event], label=event)

plt.title('Top 5 Events by Day')
plt.xlabel('Date')
plt.ylabel('Count')
plt.legend(title='Event')
plt.grid(True)
plt.show()
# Out:
# C:\Users\sadli\AppData\Local\Temp\ipykernel_21544\3082429642.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top5_df['timecreated'] = pd.to_datetime(top5_df['timecreated'])
# C:\Users\sadli\AppData\Local\Temp\ipykernel_21544\3082429642.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top5_df['date'] = top5_df['timecreated'].dt.date

# %% [markdown]
# ### Top 5 and bottom 5 actions

# %%
action_counts = lecturer_df['action'].value_counts()

lecturer_top5_actions = action_counts.head(5)
lecturer_bot5_actions = action_counts.tail(5)

# %%
lecturer_combined_actions = pd.concat([lecturer_top5_actions, lecturer_bot5_actions])

# %%
plt.figure(figsize=(12, 6))
bars = lecturer_combined_actions.plot(kind='bar', color=['skyblue']*5 + ['salmon']*5)
plt.title('Actions by Frequency (Lecturer)')
plt.xlabel('Actions')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.tight_layout()

for i, v in enumerate(lecturer_combined_actions):
    bars.text(i, v + 0.2, str(v), ha='center', va='bottom')

plt.show()

# %% [markdown]
# ### Top 5 and Bottom 5 components

# %%
component_counts = lecturer_df['component'].value_counts()

lecturer_top5_components = component_counts.head(5)
lecturer_bot5_components = component_counts.tail(5)

# %%
lecturer_combined_components = pd.concat([lecturer_top5_components, lecturer_bot5_components])

# %%
plt.figure(figsize=(12, 6))
bars = lecturer_combined_components.plot(kind='bar', color=['skyblue']*5 + ['salmon']*5)
plt.title('Components by Frequency (Lecturer)')
plt.xlabel('Components')
plt.ylabel('Frequency')
plt.xticks(rotation=45)

for i, v in enumerate(lecturer_combined_components):
    bars.text(i, v + 0.2, str(v), ha='center', va='bottom')

plt.show()

# %%
# lecturer_df['caseId'] =  lecturer_df['userid'].astype(str) + lecturer_df['courseid'].astype(str)

# %%
# lecturer_df

# %%
# lecturer_df.to_csv('../cleaned_dataset/Lecturer/FTE_Lecturer.csv')

# %% [markdown]
# ## Student EDA

# %%
# Select the student data
student_df = filtered_df[filtered_df['edulevel'] == 2]
# student_df

# %% [markdown]
# ### Check how manu unique values in each column

# %%
for col in student_df.columns:
    n = len(pd.unique(student_df[col]))
    print("{:<20}: {:<}".format(col, n))
# Out:
# id                  : 6032292
# eventname           : 66
# component           : 26
# action              : 13
# target              : 28
# crud                : 4
# edulevel            : 1
# userid              : 3680
# courseid            : 668
# timecreated         : 2854409
# event               : 66

# %% [markdown]
# ### Events over time

# %%
student_events_by_day = student_df.groupby(student_df['timecreated'].dt.date).size()

# %%
# Calculate the average number of events per day
average_events_per_day = student_events_by_day.mean()

# PLot the distribution of events over time
plt.figure(figsize=(10, 6))
student_events_by_day.plot(kind='line', marker='o', color='b')
plt.axhline(y=average_events_per_day, color='r', linestyle='--', label='Average Events per Day') # Add the average line
plt.title('Distribution of Events Over Time')
plt.xlabel('Date')
plt.ylabel('Number of Events')
plt.grid(True)
plt.xticks(rotation=45) # Rotate x-axis labels for better readability
plt.legend() # Show legend
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Top 5 and bottom 5 of events frequencies

# %%
event_counts = student_df['event'].value_counts()

student_top5_events = event_counts.head(5)
student_bottom5_events = event_counts.tail(5)

# %%
student_combined_events = pd.concat([student_top5_events, student_bottom5_events])

# %%
plt.figure(figsize=(12, 6))
bars = student_combined_events.plot(kind='bar', color=['skyblue']*5 + ['salmon']*5)
plt.title('Top 5 and Bottom 5 Event by frequency (Student)')
plt.xlabel('Events')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.tight_layout()

for i, v in enumerate(student_combined_events):
    bars.text(i, v + 0.2, str(v), ha='center', va='bottom')

plt.show()

# %%
plt.figure(figsize=(12, 6))
bars = student_combined_events.plot(kind='bar', color=['skyblue']*5 + ['salmon']*5)
plt.title('Top 5 and Bottom 5 Event by frequency (Student)')
plt.xlabel('Events')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.tight_layout()

for i, v in enumerate(student_combined_events):
    bars.text(i, v + 0.2, str(v), ha='center', va='bottom')

plt.show()

# %%
# Get the top 5 events
event_counts = student_df['event'].value_counts()
student_top5_events = event_counts.head(5).index

# Filter the dataframe to include only the top 5 events
top5_df = student_df[student_df['event'].isin(student_top5_events)]

# Convert 'timecreated' to datetime if it's not already
top5_df['timecreated'] = pd.to_datetime(top5_df['timecreated'])

# Extract the date from 'timecreated'
top5_df['date'] = top5_df['timecreated'].dt.date

# Group by 'event' and 'date' and count occurrences
event_by_day = top5_df.groupby(['date', 'event']).size().unstack(fill_value=0)

# Plot the data
plt.figure(figsize=(12, 8))
for event in student_top5_events:
    plt.plot(event_by_day.index, event_by_day[event], label=event)

plt.title('Top 5 Events by Day')
plt.xlabel('Date')
plt.ylabel('Count')
plt.legend(title='Event')
plt.grid(True)
plt.show()
# Out:
# C:\Users\sadli\AppData\Local\Temp\ipykernel_21544\3445429130.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top5_df['timecreated'] = pd.to_datetime(top5_df['timecreated'])
# C:\Users\sadli\AppData\Local\Temp\ipykernel_21544\3445429130.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top5_df['date'] = top5_df['timecreated'].dt.date

# %% [markdown]
# ### Top 5 and Bottom 5 action

# %%
action_counts = student_df['action'].value_counts()

student_top5_actions = action_counts.head(5)
student_bot5_actions = action_counts.tail(5)

# %%
student_combined_actions = pd.concat([student_top5_actions, student_bot5_actions])

# %%
plt.figure(figsize=(12, 6))
bars = student_combined_actions.plot(kind='bar', color=['skyblue']*5 + ['salmon']*5)
plt.title('Actions by Frequency (Student)')
plt.xlabel('Actions')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.tight_layout()

for i, v in enumerate(student_combined_actions):
    bars.text(i, v + 0.2, str(v), ha='center', va='bottom')

plt.show()

# %% [markdown]
# ### Top 5 and Bottom 5 of Components

# %%
component_counts = student_df['component'].value_counts()

student_top5_components = component_counts.head(5)
student_bot5_components = component_counts.tail(5)

# %%
student_combined_components = pd.concat([student_top5_components, student_bot5_components])

# %%
plt.figure(figsize=(12, 6))
bars = student_combined_components.plot(kind='bar', color=['skyblue']*5 + ['salmon']*5)
plt.title('Components by Frequency (Student)')
plt.xlabel('Components')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.tight_layout()

for i, v in enumerate(student_combined_components):
    bars.text(i, v + 0.2, str(v), ha='center', va='bottom')

plt.show()

# %%
# student_df['caseId'] =  student_df['userid'].astype(str) + student_df['courseid'].astype(str)

# %%
# student_df.to_csv('../cleaned_dataset/Student/FTE_Student.csv')

# %%
# %reset -f

# %%
component_counts
# Out:
# mod_quiz                       2819245
# core                           1421594
# mod_assign                     1056741
# assignsubmission_file           221288
# mod_resource                    173008
# mod_forum                       125020
# quizaccess_seb                   66966
# mod_url                          54710
# mod_hvp                          26710
# assignsubmission_onlinetext      26642
# gradereport_user                 16050
# mod_chat                          8837
# mod_googlemeet                    5722
# mod_groupselect                   3402
# mod_page                          2298
# mod_attendance                    1341
# mod_folder                         934
# assignsubmission_comments          729
# gradereport_overview               640
# mod_choice                         187
# mod_workshop                       103
# mod_activequiz                      99
# mod_wiki                            42
# mod_book                            27
# mod_glossary                        26
# mod_feedback                        15
# Name: component, dtype: int64

# %%
student_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6032376 entries, 0 to 7716634
# Data columns (total 11 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   id           int64
#  1   eventname    object
#  2   component    object
#  3   action       object
#  4   target       object
#  5   crud         object
#  6   edulevel     int64
#  7   userid       int64
#  8   courseid     int64
#  9   timecreated  datetime64[ns]
#  10  event        object
# dtypes: datetime64[ns](1), int64(4), object(6)
# memory usage: 552.3+ MB

# %%
lecturer_df.to_csv('../../cleaned_dataset/Lecturer/FTE_Lecturer.csv')
student_df.to_csv('../../cleaned_dataset/Student/FTE_Student.csv')

# %%
# %reset -f
