# %%
import pandas as pd

# %% [markdown]
# ## Reading dataset and check the info

# %%
df = pd.read_csv("../../dataset/All/22232-FIT.csv")

# %%
df
# Out:
#                 id                                    eventname  \
# 0        822568324                    \core\event\course_viewed
# 1        822597638                    \core\event\course_viewed
# 2        822603841                 \core\event\user_list_viewed
# 3        822607969             \core\event\badge_listing_viewed
# 4        822608234  \gradereport_user\event\grade_report_viewed
# ...            ...                                          ...
# 2650997  900652008               \mod_quiz\event\attempt_viewed
# 2650998  900652010               \mod_quiz\event\attempt_viewed
# 2650999  900652011       \mod_quiz\event\attempt_summary_viewed
# 2651000  900652012             \mod_quiz\event\attempt_reviewed
# 2651001  900652019         \mod_quiz\event\course_module_viewed
#
#                 component    action           target    objecttable  \
# 0                    core    viewed           course            NaN
# 1                    core    viewed           course            NaN
# 2                    core    viewed        user_list         course
# 3                    core    viewed    badge_listing            NaN
# 4        gradereport_user    viewed     grade_report            NaN
# ...                   ...       ...              ...            ...
# 2650997          mod_quiz    viewed          attempt  quiz_attempts
# 2650998          mod_quiz    viewed          attempt  quiz_attempts
# 2650999          mod_quiz    viewed  attempt_summary  quiz_attempts
# 2651000          mod_quiz  reviewed          attempt  quiz_attempts
# 2651001          mod_quiz    viewed    course_module           quiz
#
#           objectid crud  edulevel  contextid  ...  contextinstanceid  userid  \
# 0              NaN    r         2    3631241  ...              29880   51802
# 1              NaN    r         2    3631241  ...              29880   51802
# 2          29880.0    r         0    3631241  ...              29880   51802
# 3              NaN    r         2    3631241  ...              29880   51802
# 4              NaN    r         2    3631241  ...              29880   51802
# ...            ...  ...       ...        ...  ...                ...     ...
# 2650997  7191595.0    r         2    3981605  ...            3064832   23972
# 2650998  7191595.0    r         2    3981605  ...            3064832   23972
# 2650999  7191595.0    r         1    3981605  ...            3064832   23972
# 2651000  7191595.0    r         1    3981605  ...            3064832   23972
# 2651001   354436.0    r         2    3981605  ...            3064832   23972
#
#          courseid  relateduserid  anonymous  \
# 0           29880            NaN          0
# 1           29880            NaN          0
# 2           29880            NaN          0
# 3           29880            NaN          0
# 4           29880        51802.0          0
# ...           ...            ...        ...
# 2650997     34699        23972.0          0
# 2650998     34699        23972.0          0
# 2650999     34699        23972.0          0
# 2651000     34699        23972.0          0
# 2651001     34699            NaN          0
#
#                                                      other timecreated  \
# 0                                                       N;  1679618159
# 1                                                       N;  1679621860
# 2        a:2:{s:15:"courseshortname";s:22:"VPI3GC-D3TT-...  1679622336
# 3        a:2:{s:9:"badgetype";i:2;s:8:"courseid";s:5:"2...  1679622696
# 4                                                       N;  1679622718
# ...                                                    ...         ...
# 2650997                   a:1:{s:6:"quizid";s:6:"354436";}  1691470442
# 2650998                   a:1:{s:6:"quizid";s:6:"354436";}  1691470445
# 2650999                   a:1:{s:6:"quizid";s:6:"354436";}  1691470448
# 2651000                   a:1:{s:6:"quizid";s:6:"354436";}  1691470454
# 2651001                                                 N;  1691470469
#
#          origin               ip realuserid
# 0           web    103.190.47.63        NaN
# 1           web    103.190.47.63        NaN
# 2           web    103.190.47.63        NaN
# 3           web    103.190.47.63        NaN
# 4           web    103.190.47.63        NaN
# ...         ...              ...        ...
# 2650997     web  103.233.100.234        NaN
# 2650998     web  103.233.100.234        NaN
# 2650999     web  103.233.100.234        NaN
# 2651000     web  103.233.100.234        NaN
# 2651001     web  103.233.100.234        NaN
#
# [2651002 rows x 21 columns]

# %%
df.shape
# Out:
# (2651002, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2651002 entries, 0 to 2651001
# Data columns (total 21 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   id                 int64
#  1   eventname          object
#  2   component          object
#  3   action             object
#  4   target             object
#  5   objecttable        object
#  6   objectid           float64
#  7   crud               object
#  8   edulevel           int64
#  9   contextid          int64
#  10  contextlevel       int64
#  11  contextinstanceid  int64
#  12  userid             int64
#  13  courseid           int64
#  14  relateduserid      float64
#  15  anonymous          int64
#  16  other              object
#  17  timecreated        int64
#  18  origin             object
#  19  ip                 object
#  20  realuserid         float64
# dtypes: float64(3), int64(9), object(9)
# memory usage: 424.7+ MB

# %% [markdown]
# ## Count unique values in each column

# %%
for col in df.columns:
    n = len(pd.unique(df[col]))
    print("{:<20}: {:<}".format(col, n))
# Out:
# id                  : 2651002
# eventname           : 166
# component           : 43
# action              : 28
# target              : 72
# objecttable         : 56
# objectid            : 388597
# crud                : 4
# edulevel            : 3
# contextid           : 29635
# contextlevel        : 2
# contextinstanceid   : 29635
# userid              : 2464
# courseid            : 481
# relateduserid       : 2351
# anonymous           : 2
# other               : 164330
# timecreated         : 1519941
# origin              : 4
# ip                  : 32652
# realuserid          : 1

# %% [markdown]
# ## Check if there is null values

# %%
df.isnull().sum()
# Out:
# id                         0
# eventname                  0
# component                  0
# action                     0
# target                     0
# objecttable           690030
# objectid              690030
# crud                       0
# edulevel                   0
# contextid                  0
# contextlevel               0
# contextinstanceid          0
# userid                     0
# courseid                   0
# relateduserid        1424277
# anonymous                  0
# other                      0
# timecreated                0
# origin                     0
# ip                      7933
# realuserid           2651002
# dtype: int64

# %% [markdown]
# ## Change time from epoch to datetime

# %% [markdown]
# ### Convert the time to datetime

# %%
df['timecreated'] = pd.to_datetime(df['timecreated'], unit='s')
df
# Out:
#                 id                                    eventname  \
# 0        822568324                    \core\event\course_viewed
# 1        822597638                    \core\event\course_viewed
# 2        822603841                 \core\event\user_list_viewed
# 3        822607969             \core\event\badge_listing_viewed
# 4        822608234  \gradereport_user\event\grade_report_viewed
# ...            ...                                          ...
# 2650997  900652008               \mod_quiz\event\attempt_viewed
# 2650998  900652010               \mod_quiz\event\attempt_viewed
# 2650999  900652011       \mod_quiz\event\attempt_summary_viewed
# 2651000  900652012             \mod_quiz\event\attempt_reviewed
# 2651001  900652019         \mod_quiz\event\course_module_viewed
#
#                 component    action           target    objecttable  \
# 0                    core    viewed           course            NaN
# 1                    core    viewed           course            NaN
# 2                    core    viewed        user_list         course
# 3                    core    viewed    badge_listing            NaN
# 4        gradereport_user    viewed     grade_report            NaN
# ...                   ...       ...              ...            ...
# 2650997          mod_quiz    viewed          attempt  quiz_attempts
# 2650998          mod_quiz    viewed          attempt  quiz_attempts
# 2650999          mod_quiz    viewed  attempt_summary  quiz_attempts
# 2651000          mod_quiz  reviewed          attempt  quiz_attempts
# 2651001          mod_quiz    viewed    course_module           quiz
#
#           objectid crud  edulevel  contextid  ...  contextinstanceid  userid  \
# 0              NaN    r         2    3631241  ...              29880   51802
# 1              NaN    r         2    3631241  ...              29880   51802
# 2          29880.0    r         0    3631241  ...              29880   51802
# 3              NaN    r         2    3631241  ...              29880   51802
# 4              NaN    r         2    3631241  ...              29880   51802
# ...            ...  ...       ...        ...  ...                ...     ...
# 2650997  7191595.0    r         2    3981605  ...            3064832   23972
# 2650998  7191595.0    r         2    3981605  ...            3064832   23972
# 2650999  7191595.0    r         1    3981605  ...            3064832   23972
# 2651000  7191595.0    r         1    3981605  ...            3064832   23972
# 2651001   354436.0    r         2    3981605  ...            3064832   23972
#
#          courseid  relateduserid  anonymous  \
# 0           29880            NaN          0
# 1           29880            NaN          0
# 2           29880            NaN          0
# 3           29880            NaN          0
# 4           29880        51802.0          0
# ...           ...            ...        ...
# 2650997     34699        23972.0          0
# 2650998     34699        23972.0          0
# 2650999     34699        23972.0          0
# 2651000     34699        23972.0          0
# 2651001     34699            NaN          0
#
#                                                      other  \
# 0                                                       N;
# 1                                                       N;
# 2        a:2:{s:15:"courseshortname";s:22:"VPI3GC-D3TT-...
# 3        a:2:{s:9:"badgetype";i:2;s:8:"courseid";s:5:"2...
# 4                                                       N;
# ...                                                    ...
# 2650997                   a:1:{s:6:"quizid";s:6:"354436";}
# 2650998                   a:1:{s:6:"quizid";s:6:"354436";}
# 2650999                   a:1:{s:6:"quizid";s:6:"354436";}
# 2651000                   a:1:{s:6:"quizid";s:6:"354436";}
# 2651001                                                 N;
#
#                 timecreated origin               ip realuserid
# 0       2023-03-24 00:35:59    web    103.190.47.63        NaN
# 1       2023-03-24 01:37:40    web    103.190.47.63        NaN
# 2       2023-03-24 01:45:36    web    103.190.47.63        NaN
# 3       2023-03-24 01:51:36    web    103.190.47.63        NaN
# 4       2023-03-24 01:51:58    web    103.190.47.63        NaN
# ...                     ...    ...              ...        ...
# 2650997 2023-08-08 04:54:02    web  103.233.100.234        NaN
# 2650998 2023-08-08 04:54:05    web  103.233.100.234        NaN
# 2650999 2023-08-08 04:54:08    web  103.233.100.234        NaN
# 2651000 2023-08-08 04:54:14    web  103.233.100.234        NaN
# 2651001 2023-08-08 04:54:29    web  103.233.100.234        NaN
#
# [2651002 rows x 21 columns]

# %% [markdown]
# ### Check the range of the dataset

# %%
# Find the minimum and maximum dates
min_date = df['timecreated'].min()
max_date = df['timecreated'].max()

print('Minimum date:', min_date)
print('Maximum date:', max_date)
# Out:
# Minimum date: 2023-03-21 03:09:04
# Maximum date: 2024-03-19 02:29:37

# %% [markdown]
# ## Remove uneccessary columns

# %%
df = df.drop(columns = ['objecttable', 'objectid', 'contextid', 
                         'contextlevel', 'contextinstanceid', 'relateduserid',
                         'anonymous', 'other', 'origin', 'ip', 'realuserid'])
df
# Out:
#                 id                                    eventname  \
# 0        822568324                    \core\event\course_viewed
# 1        822597638                    \core\event\course_viewed
# 2        822603841                 \core\event\user_list_viewed
# 3        822607969             \core\event\badge_listing_viewed
# 4        822608234  \gradereport_user\event\grade_report_viewed
# ...            ...                                          ...
# 2650997  900652008               \mod_quiz\event\attempt_viewed
# 2650998  900652010               \mod_quiz\event\attempt_viewed
# 2650999  900652011       \mod_quiz\event\attempt_summary_viewed
# 2651000  900652012             \mod_quiz\event\attempt_reviewed
# 2651001  900652019         \mod_quiz\event\course_module_viewed
#
#                 component    action           target crud  edulevel  userid  \
# 0                    core    viewed           course    r         2   51802
# 1                    core    viewed           course    r         2   51802
# 2                    core    viewed        user_list    r         0   51802
# 3                    core    viewed    badge_listing    r         2   51802
# 4        gradereport_user    viewed     grade_report    r         2   51802
# ...                   ...       ...              ...  ...       ...     ...
# 2650997          mod_quiz    viewed          attempt    r         2   23972
# 2650998          mod_quiz    viewed          attempt    r         2   23972
# 2650999          mod_quiz    viewed  attempt_summary    r         1   23972
# 2651000          mod_quiz  reviewed          attempt    r         1   23972
# 2651001          mod_quiz    viewed    course_module    r         2   23972
#
#          courseid         timecreated
# 0           29880 2023-03-24 00:35:59
# 1           29880 2023-03-24 01:37:40
# 2           29880 2023-03-24 01:45:36
# 3           29880 2023-03-24 01:51:36
# 4           29880 2023-03-24 01:51:58
# ...           ...                 ...
# 2650997     34699 2023-08-08 04:54:02
# 2650998     34699 2023-08-08 04:54:05
# 2650999     34699 2023-08-08 04:54:08
# 2651000     34699 2023-08-08 04:54:14
# 2651001     34699 2023-08-08 04:54:29
#
# [2651002 rows x 10 columns]

# %%
df.isnull().sum()
# Out:
# id             0
# eventname      0
# component      0
# action         0
# target         0
# crud           0
# edulevel       0
# userid         0
# courseid       0
# timecreated    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2651002 entries, 0 to 2651001
# Data columns (total 10 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   id           int64
#  1   eventname    object
#  2   component    object
#  3   action       object
#  4   target       object
#  5   crud         object
#  6   edulevel     int64
#  7   userid       int64
#  8   courseid     int64
#  9   timecreated  datetime64[ns]
# dtypes: datetime64[ns](1), int64(4), object(5)
# memory usage: 202.3+ MB

# %% [markdown]
# ## Check if there is duplicates data and remove it

# %% [markdown]
# ### Check for duplicates

# %%
duplicate_mask = df.duplicated(keep=False)

duplicate_rows = df[duplicate_mask]
duplicate_rows
# Out:
# Empty DataFrame
# Columns: [id, eventname, component, action, target, crud, edulevel, userid, courseid, timecreated]
# Index: []

# %% [markdown]
# ### Drop duplicates

# %%
df.drop_duplicates()
# Out:
#                 id                                    eventname  \
# 0        822568324                    \core\event\course_viewed
# 1        822597638                    \core\event\course_viewed
# 2        822603841                 \core\event\user_list_viewed
# 3        822607969             \core\event\badge_listing_viewed
# 4        822608234  \gradereport_user\event\grade_report_viewed
# ...            ...                                          ...
# 2650997  900652008               \mod_quiz\event\attempt_viewed
# 2650998  900652010               \mod_quiz\event\attempt_viewed
# 2650999  900652011       \mod_quiz\event\attempt_summary_viewed
# 2651000  900652012             \mod_quiz\event\attempt_reviewed
# 2651001  900652019         \mod_quiz\event\course_module_viewed
#
#                 component    action           target crud  edulevel  userid  \
# 0                    core    viewed           course    r         2   51802
# 1                    core    viewed           course    r         2   51802
# 2                    core    viewed        user_list    r         0   51802
# 3                    core    viewed    badge_listing    r         2   51802
# 4        gradereport_user    viewed     grade_report    r         2   51802
# ...                   ...       ...              ...  ...       ...     ...
# 2650997          mod_quiz    viewed          attempt    r         2   23972
# 2650998          mod_quiz    viewed          attempt    r         2   23972
# 2650999          mod_quiz    viewed  attempt_summary    r         1   23972
# 2651000          mod_quiz  reviewed          attempt    r         1   23972
# 2651001          mod_quiz    viewed    course_module    r         2   23972
#
#          courseid         timecreated
# 0           29880 2023-03-24 00:35:59
# 1           29880 2023-03-24 01:37:40
# 2           29880 2023-03-24 01:45:36
# 3           29880 2023-03-24 01:51:36
# 4           29880 2023-03-24 01:51:58
# ...           ...                 ...
# 2650997     34699 2023-08-08 04:54:02
# 2650998     34699 2023-08-08 04:54:05
# 2650999     34699 2023-08-08 04:54:08
# 2651000     34699 2023-08-08 04:54:14
# 2651001     34699 2023-08-08 04:54:29
#
# [2651002 rows x 10 columns]

# %% [markdown]
# ## Shortened the event name

# %%
shortened = list(value.split('\\')[1] + "\\" +  value.split('\\')[-1] for value in df["eventname"])
df["event"] = shortened
df
# Out:
#                 id                                    eventname  \
# 0        822568324                    \core\event\course_viewed
# 1        822597638                    \core\event\course_viewed
# 2        822603841                 \core\event\user_list_viewed
# 3        822607969             \core\event\badge_listing_viewed
# 4        822608234  \gradereport_user\event\grade_report_viewed
# ...            ...                                          ...
# 2650997  900652008               \mod_quiz\event\attempt_viewed
# 2650998  900652010               \mod_quiz\event\attempt_viewed
# 2650999  900652011       \mod_quiz\event\attempt_summary_viewed
# 2651000  900652012             \mod_quiz\event\attempt_reviewed
# 2651001  900652019         \mod_quiz\event\course_module_viewed
#
#                 component    action           target crud  edulevel  userid  \
# 0                    core    viewed           course    r         2   51802
# 1                    core    viewed           course    r         2   51802
# 2                    core    viewed        user_list    r         0   51802
# 3                    core    viewed    badge_listing    r         2   51802
# 4        gradereport_user    viewed     grade_report    r         2   51802
# ...                   ...       ...              ...  ...       ...     ...
# 2650997          mod_quiz    viewed          attempt    r         2   23972
# 2650998          mod_quiz    viewed          attempt    r         2   23972
# 2650999          mod_quiz    viewed  attempt_summary    r         1   23972
# 2651000          mod_quiz  reviewed          attempt    r         1   23972
# 2651001          mod_quiz    viewed    course_module    r         2   23972
#
#          courseid         timecreated                                 event
# 0           29880 2023-03-24 00:35:59                    core\course_viewed
# 1           29880 2023-03-24 01:37:40                    core\course_viewed
# 2           29880 2023-03-24 01:45:36                 core\user_list_viewed
# 3           29880 2023-03-24 01:51:36             core\badge_listing_viewed
# 4           29880 2023-03-24 01:51:58  gradereport_user\grade_report_viewed
# ...           ...                 ...                                   ...
# 2650997     34699 2023-08-08 04:54:02               mod_quiz\attempt_viewed
# 2650998     34699 2023-08-08 04:54:05               mod_quiz\attempt_viewed
# 2650999     34699 2023-08-08 04:54:08       mod_quiz\attempt_summary_viewed
# 2651000     34699 2023-08-08 04:54:14             mod_quiz\attempt_reviewed
# 2651001     34699 2023-08-08 04:54:29         mod_quiz\course_module_viewed
#
# [2651002 rows x 11 columns]

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ### Distribution of Events Over Time

# %%
events_by_day = df.groupby(df['timecreated'].dt.date).size()

# %%
# PLot the distribution of events over time
plt.figure(figsize=(10, 6))
events_by_day.plot(kind='line', marker='o', color='b')
plt.title('Distribution of Events Over Time')
plt.xlabel('Date')
plt.ylabel('Number of Events')
plt.grid(True)
plt.xticks(rotation=45) # Rotate x-axis labels for better readability
plt.tight_layout()
plt.show()

# %%
# Filter data between two dates
filtered_df = df.loc[(df['timecreated'] < '2023-06-26')]

# %%
filtered_events_by_day = filtered_df.groupby(filtered_df['timecreated'].dt.date).size()

# %%
# PLot the distribution of events over time
plt.figure(figsize=(10, 6))
filtered_events_by_day.plot(kind='line', marker='o', color='b')
plt.title('Distribution of Events Over Time')
plt.xlabel('Date')
plt.ylabel('Number of Events')
plt.grid(True)
plt.xticks(rotation=45) # Rotate x-axis labels for better readability
plt.tight_layout()
plt.show()

# %%
# Group events by educational level and calculate the frequency of events for each level
events_by_edulevel = filtered_df.groupby('edulevel').size()

# %%
# Plot the distribution of events across different educational levels
plt.figure(figsize=(10, 6))
events_by_edulevel.plot(kind='bar', color='salmon')
plt.title('Distribution of Events Across Educational Levels')
plt.xlabel('Educational Level')
plt.ylabel('Frequency of Events')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Admin EDA

# %%
# Select the admin data
admin_df = filtered_df[filtered_df['edulevel'] == 0]
# admin_df

# %% [markdown]
# ### Count how many unique values in each column

# %%
for col in admin_df.columns:
    n = len(pd.unique(admin_df[col]))
    print("{:<20}: {:<}".format(col, n))
# Out:
# id                  : 344081
# eventname           : 36
# component           : 9
# action              : 9
# target              : 24
# crud                : 4
# edulevel            : 1
# userid              : 2300
# courseid            : 430
# timecreated         : 274801
# event               : 36

# %% [markdown]
# ### Events over time

# %%
admin_events_by_day = admin_df.groupby(admin_df['timecreated'].dt.date).size()

# %%
# Calculate the average number of events per day
average_events_per_day = admin_events_by_day.mean()

# PLot the distribution of events over time
plt.figure(figsize=(10, 6))
admin_events_by_day.plot(kind='line', marker='o', color='b')
plt.axhline(y=average_events_per_day, color='r', linestyle='--', label='Average Events per Day') # Add the average line
plt.title('Distribution of Events Over Time')
plt.xlabel('Date')
plt.ylabel('Number of Events')
plt.grid(True)
plt.xticks(rotation=45) # Rotate x-axis labels for better readability
plt.legend() # Show legend
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Top 5 and bottom 5 of event frequencies

# %%
event_counts = admin_df['event'].value_counts()

admin_top5_events = event_counts.head(5)
admin_bottom5_events = event_counts.tail(5)

# %%
admin_combined_events = pd.concat([admin_top5_events, admin_bottom5_events])

# %%
plt.figure(figsize=(12, 6))
bars = admin_combined_events.plot(kind='bar', color=['skyblue']*5 + ['salmon']*5)
plt.title('Top 5 and Bottom 5 Events by Frequency (Admin)')
plt.xlabel('Events')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.tight_layout()

for i, v in enumerate(admin_combined_events):
    bars.text(i, v + 0.2, str(v), ha='center', va='bottom')
    
plt.show()

# %% [markdown]
# ### Top 5 and bottom 5 action

# %%
action_counts = admin_df['action'].value_counts()

admin_top5_actions = action_counts.head(5)
admin_bot5_actions = action_counts.tail(4)

# %%
admin_combined_actions = pd.concat([admin_top5_actions, admin_bot5_actions])

# %%
plt.figure(figsize=(12, 6))
bars = admin_combined_actions.plot(kind='bar', color=['skyblue']*5 + ['salmon']*5)
plt.title('Actions by Frequency (Admin)')
plt.xlabel('Actions')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.tight_layout()

for i, v in enumerate(admin_combined_actions):
    bars.text(i, v + 0.2, str(v), ha='center', va='bottom')

plt.show()

# %% [markdown]
# ### Top 5 and bottom 5 of components

# %%
component_counts = admin_df['component'].value_counts()

admin_top5_components = component_counts.head(4)
admin_bot5_components = component_counts.tail(3)

# %%
admin_combined_components = pd.concat([admin_top5_components, admin_bot5_components])

# %%
plt.figure(figsize=(12,6))
bars = admin_combined_components.plot(kind='bar', color=['skyblue']*5 + ['salmon']*5)
plt.title('Components by Frequency (Admin)')
plt.xlabel('Components')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.tight_layout()

for i, v in enumerate(admin_combined_components):
    bars.text(i, v + 0.2, str(v), ha='center', va='bottom')

plt.show()

# %% [markdown]
# ## Lecturer EDA

# %%
# Select the lecturer data
lecturer_df = filtered_df[filtered_df['edulevel'] == 1]
# lecturer_df

# %% [markdown]
# ### Count how many unique values in each column

# %%
for col in lecturer_df.columns:
    n = len(pd.unique(lecturer_df[col]))
    print("{:<20}: {:<}".format(col, n))
# Out:
# id                  : 197801
# eventname           : 60
# component           : 18
# action              : 16
# target              : 30
# crud                : 4
# edulevel            : 1
# userid              : 2064
# courseid            : 379
# timecreated         : 148573
# event               : 60

# %% [markdown]
# ### Events over time

# %%
lecturer_events_by_day = lecturer_df.groupby(lecturer_df['timecreated'].dt.date).size()

# %%
# Calculate the average number of events per day
average_events_per_day = lecturer_events_by_day.mean()

# PLot the distribution of events over time
plt.figure(figsize=(10, 6))
lecturer_events_by_day.plot(kind='line', marker='o', color='b')
plt.axhline(y=average_events_per_day, color='r', linestyle='--', label='Average Events per Day') # Add the average line
plt.title('Distribution of Events Over Time')
plt.xlabel('Date')
plt.ylabel('Number of Events')
plt.grid(True)
plt.xticks(rotation=45) # Rotate x-axis labels for better readability
plt.legend() # Show legend
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Top 5 and bottom 5 of event frequencies

# %%
event_counts = lecturer_df['event'].value_counts()

lecturer_top5_events = event_counts.head(5)
lecturer_bottom5_events = event_counts.tail(5)

# %%
lecturer_combined_events = pd.concat([lecturer_top5_events, lecturer_bottom5_events])

# %%
plt.figure(figsize=(12, 6))
bars = lecturer_combined_events.plot(kind='bar', color=['skyblue']*5 + ['salmon']*5)
plt.title('Top 5 and Bottom 5 Events by frequency (Lecturer)')
plt.xlabel('Events')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.tight_layout()

for i, v in enumerate(lecturer_combined_events):
    bars.text(i, v + 0.2, str(v), ha='center', va='bottom')

plt.show()

# %%
plt.figure(figsize=(12, 6))
bars = lecturer_combined_events.plot(kind='bar', color=['skyblue']*5 + ['salmon']*5)
plt.title('Top 5 and Bottom 5 Events by frequency (Lecturer)')
plt.xlabel('Events')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.tight_layout()

for i, v in enumerate(lecturer_combined_events):
    bars.text(i, v + 0.2, str(v), ha='center', va='bottom')

plt.show()

# %%
# Get the top 5 events
event_counts = lecturer_df['event'].value_counts()
lecturer_top5_events = event_counts.head(5).index

# Filter the dataframe to include only the top 5 events
top5_df = lecturer_df[lecturer_df['event'].isin(lecturer_top5_events)]

# Convert 'timecreated' to datetime if it's not already
top5_df['timecreated'] = pd.to_datetime(top5_df['timecreated'])

# Extract the date from 'timecreated'
top5_df['date'] = top5_df['timecreated'].dt.date

# Group by 'event' and 'date' and count occurrences
event_by_day = top5_df.groupby(['date', 'event']).size().unstack(fill_value=0)

# Plot the data
plt.figure(figsize=(12, 8))
for event in lecturer_top5_events:
    plt.plot(event_by_day.index, event_by_day[event], label=event)

plt.title('Top 5 Events by Day')
plt.xlabel('Date')
plt.ylabel('Count')
plt.legend(title='Event')
plt.grid(True)
plt.show()
# Out:
# C:\Users\sadli\AppData\Local\Temp\ipykernel_16556\3082429642.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top5_df['timecreated'] = pd.to_datetime(top5_df['timecreated'])
# C:\Users\sadli\AppData\Local\Temp\ipykernel_16556\3082429642.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top5_df['date'] = top5_df['timecreated'].dt.date

# %% [markdown]
# ### Top 5 and bottom 5 actions

# %%
action_counts = lecturer_df['action'].value_counts()

lecturer_top5_actions = action_counts.head(5)
lecturer_bot5_actions = action_counts.tail(5)

# %%
lecturer_combined_actions = pd.concat([lecturer_top5_actions, lecturer_bot5_actions])

# %%
plt.figure(figsize=(12, 6))
bars = lecturer_combined_actions.plot(kind='bar', color=['skyblue']*5 + ['salmon']*5)
plt.title('Actions by Frequency (Lecturer)')
plt.xlabel('Actions')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.tight_layout()

for i, v in enumerate(lecturer_combined_actions):
    bars.text(i, v + 0.2, str(v), ha='center', va='bottom')

plt.show()

# %% [markdown]
# ### Top 5 and Bottom 5 components

# %%
component_counts = lecturer_df['component'].value_counts()

lecturer_top5_components = component_counts.head(5)
lecturer_bot5_components = component_counts.tail(5)

# %%
lecturer_combined_components = pd.concat([lecturer_top5_components, lecturer_bot5_components])

# %%
plt.figure(figsize=(12, 6))
bars = lecturer_combined_components.plot(kind='bar', color=['skyblue']*5 + ['salmon']*5)
plt.title('Components by Frequency (Lecturer)')
plt.xlabel('Components')
plt.ylabel('Frequency')
plt.xticks(rotation=45)

for i, v in enumerate(lecturer_combined_components):
    bars.text(i, v + 0.2, str(v), ha='center', va='bottom')

plt.show()

# %% [markdown]
# ## Student EDA

# %%
# Select the student data
student_df = filtered_df[filtered_df['edulevel'] == 2]
# student_df

# %% [markdown]
# ### Check how manu unique values in each column

# %%
for col in student_df.columns:
    n = len(pd.unique(student_df[col]))
    print("{:<20}: {:<}".format(col, n))
# Out:
# id                  : 2097109
# eventname           : 70
# component           : 27
# action              : 14
# target              : 29
# crud                : 4
# edulevel            : 1
# userid              : 2413
# courseid            : 481
# timecreated         : 1393002
# event               : 70

# %% [markdown]
# ### Events over time

# %%
student_events_by_day = student_df.groupby(student_df['timecreated'].dt.date).size()

# %%
# Calculate the average number of events per day
average_events_per_day = student_events_by_day.mean()

# PLot the distribution of events over time
plt.figure(figsize=(10, 6))
student_events_by_day.plot(kind='line', marker='o', color='b')
plt.axhline(y=average_events_per_day, color='r', linestyle='--', label='Average Events per Day') # Add the average line
plt.title('Distribution of Events Over Time')
plt.xlabel('Date')
plt.ylabel('Number of Events')
plt.grid(True)
plt.xticks(rotation=45) # Rotate x-axis labels for better readability
plt.legend() # Show legend
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Top 5 and bottom 5 of events frequencies

# %%
event_counts = student_df['event'].value_counts()

student_top5_events = event_counts.head(5)
student_bottom5_events = event_counts.tail(5)

# %%
student_combined_events = pd.concat([student_top5_events, student_bottom5_events])

# %%
plt.figure(figsize=(12, 6))
bars = student_combined_events.plot(kind='bar', color=['skyblue']*5 + ['salmon']*5)
plt.title('Top 5 and Bottom 5 Event by frequency (Student)')
plt.xlabel('Events')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.tight_layout()

for i, v in enumerate(student_combined_events):
    bars.text(i, v + 0.2, str(v), ha='center', va='bottom')

plt.show()

# %%
plt.figure(figsize=(12, 6))
bars = student_combined_events.plot(kind='bar', color=['skyblue']*5 + ['salmon']*5)
plt.title('Top 5 and Bottom 5 Event by frequency (Student)')
plt.xlabel('Events')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.tight_layout()

for i, v in enumerate(student_combined_events):
    bars.text(i, v + 0.2, str(v), ha='center', va='bottom')

plt.show()

# %%
# Get the top 5 events
event_counts = student_df['event'].value_counts()
student_top5_events = event_counts.head(5).index

# Filter the dataframe to include only the top 5 events
top5_df = student_df[student_df['event'].isin(student_top5_events)]

# Convert 'timecreated' to datetime if it's not already
top5_df['timecreated'] = pd.to_datetime(top5_df['timecreated'])

# Extract the date from 'timecreated'
top5_df['date'] = top5_df['timecreated'].dt.date

# Group by 'event' and 'date' and count occurrences
event_by_day = top5_df.groupby(['date', 'event']).size().unstack(fill_value=0)

# Plot the data
plt.figure(figsize=(12, 8))
for event in student_top5_events:
    plt.plot(event_by_day.index, event_by_day[event], label=event)

plt.title('Top 5 Events by Day')
plt.xlabel('Date')
plt.ylabel('Count')
plt.legend(title='Event')
plt.grid(True)
plt.show()
# Out:
# C:\Users\sadli\AppData\Local\Temp\ipykernel_16556\3445429130.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top5_df['timecreated'] = pd.to_datetime(top5_df['timecreated'])
# C:\Users\sadli\AppData\Local\Temp\ipykernel_16556\3445429130.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top5_df['date'] = top5_df['timecreated'].dt.date

# %% [markdown]
# ### Top 5 and Bottom 5 action

# %%
action_counts = student_df['action'].value_counts()

student_top5_actions = action_counts.head(5)
student_bot5_actions = action_counts.tail(5)

# %%
student_combined_actions = pd.concat([student_top5_actions, student_bot5_actions])

# %%
plt.figure(figsize=(12, 6))
bars = student_combined_actions.plot(kind='bar', color=['skyblue']*5 + ['salmon']*5)
plt.title('Actions by Frequency (Student)')
plt.xlabel('Actions')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.tight_layout()

for i, v in enumerate(student_combined_actions):
    bars.text(i, v + 0.2, str(v), ha='center', va='bottom')

plt.show()

# %% [markdown]
# ### Top 5 and Bottom 5 of Components

# %%
component_counts = student_df['component'].value_counts()

student_top5_components = component_counts.head(5)
student_bot5_components = component_counts.tail(5)

# %%
student_combined_components = pd.concat([student_top5_components, student_bot5_components])

# %%
plt.figure(figsize=(12, 6))
bars = student_combined_components.plot(kind='bar', color=['skyblue']*5 + ['salmon']*5)
plt.title('Components by Frequency (Student)')
plt.xlabel('Components')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.tight_layout()

for i, v in enumerate(student_combined_components):
    bars.text(i, v + 0.2, str(v), ha='center', va='bottom')

plt.show()

# %%
lecturer_df.to_csv('../../cleaned_dataset/Lecturer/FIT_Lecturer.csv')
student_df.to_csv('../../cleaned_dataset/Student/FIT_Student.csv')

# %%
# %reset -f
