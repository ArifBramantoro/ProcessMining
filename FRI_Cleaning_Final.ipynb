# %%
import pandas as pd

# %% [markdown]
# ## Reading dataset and check the info

# %%
df = pd.read_csv("../../dataset/All/22232-FRI.csv")

# %%
df
# Out:
#                 id                                 eventname     component  \
# 0        822218468     \core\event\course_user_report_viewed          core
# 1        822224558      \mod_quiz\event\course_module_viewed      mod_quiz
# 2        824242626                 \core\event\course_viewed          core
# 3        824242791  \mod_resource\event\course_module_viewed  mod_resource
# 4        824243066  \mod_resource\event\course_module_viewed  mod_resource
# ...            ...                                       ...           ...
# 6500584  888754296          \mod_quiz\event\attempt_reviewed      mod_quiz
# 6500585  888754317          \mod_quiz\event\attempt_reviewed      mod_quiz
# 6500586  888754326      \mod_quiz\event\course_module_viewed      mod_quiz
# 6500587  888754329          \mod_quiz\event\attempt_reviewed      mod_quiz
# 6500588  888754363          \mod_quiz\event\attempt_reviewed      mod_quiz
#
#            action              target    objecttable   objectid crud  \
# 0          viewed  course_user_report            NaN        NaN    r
# 1          viewed       course_module           quiz   323293.0    r
# 2          viewed              course            NaN        NaN    r
# 3          viewed       course_module       resource   457692.0    r
# 4          viewed       course_module       resource   457694.0    r
# ...           ...                 ...            ...        ...  ...
# 6500584  reviewed             attempt  quiz_attempts  6653349.0    r
# 6500585  reviewed             attempt  quiz_attempts  6692147.0    r
# 6500586    viewed       course_module           quiz   366942.0    r
# 6500587  reviewed             attempt  quiz_attempts  7001267.0    r
# 6500588  reviewed             attempt  quiz_attempts  7001267.0    r
#
#          edulevel  contextid  ...  contextinstanceid  userid  courseid  \
# 0               2    3649582  ...              30137   70580     30137
# 1               2    3649647  ...            2737580   68637     30137
# 2               2    3649582  ...              30137   65908     30137
# 3               2    3649659  ...            2737592   65908     30137
# 4               2    3649673  ...            2737606   65908     30137
# ...           ...        ...  ...                ...     ...       ...
# 6500584         1    4044257  ...            3126910   71305     34106
# 6500585         1    4044257  ...            3126910   71305     34106
# 6500586         2    4069677  ...            3151425   71305     34106
# 6500587         1    4069677  ...            3151425   71305     34106
# 6500588         1    4069677  ...            3151425   71305     34106
#
#          relateduserid  anonymous                             other  \
# 0              70580.0          0     a:1:{s:4:"mode";s:5:"grade";}
# 1                  NaN          0                                N;
# 2                  NaN          0                                N;
# 3                  NaN          0                                N;
# 4                  NaN          0                                N;
# ...                ...        ...                               ...
# 6500584        71305.0          0  a:1:{s:6:"quizid";s:6:"362144";}
# 6500585        71305.0          0  a:1:{s:6:"quizid";s:6:"362144";}
# 6500586            NaN          0                                N;
# 6500587        71305.0          0  a:1:{s:6:"quizid";s:6:"366942";}
# 6500588        71305.0          0  a:1:{s:6:"quizid";s:6:"366942";}
#
#         timecreated  origin               ip realuserid
# 0        1679559224     web    36.71.242.139        NaN
# 1        1679559768     web    36.81.236.103        NaN
# 2        1679806755     web  125.163.109.104        NaN
# 3        1679806787     web  125.163.109.104        NaN
# 4        1679806840     web  125.163.109.104        NaN
# ...             ...     ...              ...        ...
# 6500584  1687711961     web    116.206.14.51        NaN
# 6500585  1687711981     web    116.206.14.51        NaN
# 6500586  1687711988     web    116.206.14.51        NaN
# 6500587  1687711991     web    116.206.14.51        NaN
# 6500588  1687712023     web    116.206.14.51        NaN
#
# [6500589 rows x 21 columns]

# %%
df.shape
# Out:
# (6500589, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6500589 entries, 0 to 6500588
# Data columns (total 21 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   id                 int64
#  1   eventname          object
#  2   component          object
#  3   action             object
#  4   target             object
#  5   objecttable        object
#  6   objectid           float64
#  7   crud               object
#  8   edulevel           int64
#  9   contextid          int64
#  10  contextlevel       int64
#  11  contextinstanceid  int64
#  12  userid             int64
#  13  courseid           int64
#  14  relateduserid      float64
#  15  anonymous          int64
#  16  other              object
#  17  timecreated        int64
#  18  origin             object
#  19  ip                 object
#  20  realuserid         float64
# dtypes: float64(3), int64(9), object(9)
# memory usage: 1.0+ GB

# %% [markdown]
# ## Count unique values in each column

# %%
for col in df.columns:
    n = len(pd.unique(df[col]))
    print("{:<20}: {:<}".format(col, n))
# Out:
# id                  : 6499946
# eventname           : 165
# component           : 41
# action              : 28
# target              : 69
# objecttable         : 54
# objectid            : 732739
# crud                : 4
# edulevel            : 3
# contextid           : 49077
# contextlevel        : 2
# contextinstanceid   : 49077
# userid              : 4693
# courseid            : 895
# relateduserid       : 4650
# anonymous           : 2
# other               : 346485
# timecreated         : 2799212
# origin              : 4
# ip                  : 51786
# realuserid          : 2

# %% [markdown]
# ## Check if there is null values

# %%
df.isnull().sum()
# Out:
# id                         0
# eventname                  0
# component                  0
# action                     0
# target                     0
# objecttable          1206418
# objectid             1206418
# crud                       0
# edulevel                   0
# contextid                  0
# contextlevel               0
# contextinstanceid          0
# userid                     0
# courseid                   0
# relateduserid        2664822
# anonymous                  0
# other                      0
# timecreated                0
# origin                     0
# ip                     15489
# realuserid           6500587
# dtype: int64

# %% [markdown]
# ## Change time from epoch to datetime

# %% [markdown]
# ### Convert the time to datetime

# %%
df['timecreated'] = pd.to_datetime(df['timecreated'], unit='s')
df
# Out:
#                 id                                 eventname     component  \
# 0        822218468     \core\event\course_user_report_viewed          core
# 1        822224558      \mod_quiz\event\course_module_viewed      mod_quiz
# 2        824242626                 \core\event\course_viewed          core
# 3        824242791  \mod_resource\event\course_module_viewed  mod_resource
# 4        824243066  \mod_resource\event\course_module_viewed  mod_resource
# ...            ...                                       ...           ...
# 6500584  888754296          \mod_quiz\event\attempt_reviewed      mod_quiz
# 6500585  888754317          \mod_quiz\event\attempt_reviewed      mod_quiz
# 6500586  888754326      \mod_quiz\event\course_module_viewed      mod_quiz
# 6500587  888754329          \mod_quiz\event\attempt_reviewed      mod_quiz
# 6500588  888754363          \mod_quiz\event\attempt_reviewed      mod_quiz
#
#            action              target    objecttable   objectid crud  \
# 0          viewed  course_user_report            NaN        NaN    r
# 1          viewed       course_module           quiz   323293.0    r
# 2          viewed              course            NaN        NaN    r
# 3          viewed       course_module       resource   457692.0    r
# 4          viewed       course_module       resource   457694.0    r
# ...           ...                 ...            ...        ...  ...
# 6500584  reviewed             attempt  quiz_attempts  6653349.0    r
# 6500585  reviewed             attempt  quiz_attempts  6692147.0    r
# 6500586    viewed       course_module           quiz   366942.0    r
# 6500587  reviewed             attempt  quiz_attempts  7001267.0    r
# 6500588  reviewed             attempt  quiz_attempts  7001267.0    r
#
#          edulevel  contextid  ...  contextinstanceid  userid  courseid  \
# 0               2    3649582  ...              30137   70580     30137
# 1               2    3649647  ...            2737580   68637     30137
# 2               2    3649582  ...              30137   65908     30137
# 3               2    3649659  ...            2737592   65908     30137
# 4               2    3649673  ...            2737606   65908     30137
# ...           ...        ...  ...                ...     ...       ...
# 6500584         1    4044257  ...            3126910   71305     34106
# 6500585         1    4044257  ...            3126910   71305     34106
# 6500586         2    4069677  ...            3151425   71305     34106
# 6500587         1    4069677  ...            3151425   71305     34106
# 6500588         1    4069677  ...            3151425   71305     34106
#
#          relateduserid  anonymous                             other  \
# 0              70580.0          0     a:1:{s:4:"mode";s:5:"grade";}
# 1                  NaN          0                                N;
# 2                  NaN          0                                N;
# 3                  NaN          0                                N;
# 4                  NaN          0                                N;
# ...                ...        ...                               ...
# 6500584        71305.0          0  a:1:{s:6:"quizid";s:6:"362144";}
# 6500585        71305.0          0  a:1:{s:6:"quizid";s:6:"362144";}
# 6500586            NaN          0                                N;
# 6500587        71305.0          0  a:1:{s:6:"quizid";s:6:"366942";}
# 6500588        71305.0          0  a:1:{s:6:"quizid";s:6:"366942";}
#
#                 timecreated origin               ip realuserid
# 0       2023-03-23 08:13:44    web    36.71.242.139        NaN
# 1       2023-03-23 08:22:48    web    36.81.236.103        NaN
# 2       2023-03-26 04:59:15    web  125.163.109.104        NaN
# 3       2023-03-26 04:59:47    web  125.163.109.104        NaN
# 4       2023-03-26 05:00:40    web  125.163.109.104        NaN
# ...                     ...    ...              ...        ...
# 6500584 2023-06-25 16:52:41    web    116.206.14.51        NaN
# 6500585 2023-06-25 16:53:01    web    116.206.14.51        NaN
# 6500586 2023-06-25 16:53:08    web    116.206.14.51        NaN
# 6500587 2023-06-25 16:53:11    web    116.206.14.51        NaN
# 6500588 2023-06-25 16:53:43    web    116.206.14.51        NaN
#
# [6500589 rows x 21 columns]

# %% [markdown]
# ### Check the range of the dataset

# %%
# Find the minimum and maximum dates
min_date = df['timecreated'].min()
max_date = df['timecreated'].max()

print('Minimum date:', min_date)
print('Maximum date:', max_date)
# Out:
# Minimum date: 2023-03-23 07:46:20
# Maximum date: 2024-03-22 04:12:58

# %% [markdown]
# ## Remove uneccessary columns

# %%
df = df.drop(columns = ['objecttable', 'objectid', 'contextid', 
                         'contextlevel', 'contextinstanceid', 'relateduserid',
                         'anonymous', 'other', 'origin', 'ip', 'realuserid'])
df
# Out:
#                 id                                 eventname     component  \
# 0        822218468     \core\event\course_user_report_viewed          core
# 1        822224558      \mod_quiz\event\course_module_viewed      mod_quiz
# 2        824242626                 \core\event\course_viewed          core
# 3        824242791  \mod_resource\event\course_module_viewed  mod_resource
# 4        824243066  \mod_resource\event\course_module_viewed  mod_resource
# ...            ...                                       ...           ...
# 6500584  888754296          \mod_quiz\event\attempt_reviewed      mod_quiz
# 6500585  888754317          \mod_quiz\event\attempt_reviewed      mod_quiz
# 6500586  888754326      \mod_quiz\event\course_module_viewed      mod_quiz
# 6500587  888754329          \mod_quiz\event\attempt_reviewed      mod_quiz
# 6500588  888754363          \mod_quiz\event\attempt_reviewed      mod_quiz
#
#            action              target crud  edulevel  userid  courseid  \
# 0          viewed  course_user_report    r         2   70580     30137
# 1          viewed       course_module    r         2   68637     30137
# 2          viewed              course    r         2   65908     30137
# 3          viewed       course_module    r         2   65908     30137
# 4          viewed       course_module    r         2   65908     30137
# ...           ...                 ...  ...       ...     ...       ...
# 6500584  reviewed             attempt    r         1   71305     34106
# 6500585  reviewed             attempt    r         1   71305     34106
# 6500586    viewed       course_module    r         2   71305     34106
# 6500587  reviewed             attempt    r         1   71305     34106
# 6500588  reviewed             attempt    r         1   71305     34106
#
#                 timecreated
# 0       2023-03-23 08:13:44
# 1       2023-03-23 08:22:48
# 2       2023-03-26 04:59:15
# 3       2023-03-26 04:59:47
# 4       2023-03-26 05:00:40
# ...                     ...
# 6500584 2023-06-25 16:52:41
# 6500585 2023-06-25 16:53:01
# 6500586 2023-06-25 16:53:08
# 6500587 2023-06-25 16:53:11
# 6500588 2023-06-25 16:53:43
#
# [6500589 rows x 10 columns]

# %%
df.isnull().sum()
# Out:
# id             0
# eventname      0
# component      0
# action         0
# target         0
# crud           0
# edulevel       0
# userid         0
# courseid       0
# timecreated    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6500589 entries, 0 to 6500588
# Data columns (total 10 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   id           int64
#  1   eventname    object
#  2   component    object
#  3   action       object
#  4   target       object
#  5   crud         object
#  6   edulevel     int64
#  7   userid       int64
#  8   courseid     int64
#  9   timecreated  datetime64[ns]
# dtypes: datetime64[ns](1), int64(4), object(5)
# memory usage: 496.0+ MB

# %% [markdown]
# ## Check if there is duplicates data and remove it

# %% [markdown]
# ### Check for duplicates

# %%
duplicate_mask = df.duplicated(keep=False)

duplicate_rows = df[duplicate_mask]
duplicate_rows
# Out:
#                 id                                 eventname   component  \
# 4362998  832082277    \mod_assign\event\course_module_viewed  mod_assign
# 4362999  832082277    \mod_assign\event\course_module_viewed  mod_assign
# 4363000  832082278  \mod_assign\event\submission_form_viewed  mod_assign
# 4363001  832082278  \mod_assign\event\submission_form_viewed  mod_assign
# 4363002  832086521    \mod_assign\event\course_module_viewed  mod_assign
# ...            ...                                       ...         ...
# 4371288  888369146    \mod_assign\event\grading_table_viewed  mod_assign
# 4371289  888369151     \mod_assign\event\grading_form_viewed  mod_assign
# 4371290  888369151     \mod_assign\event\grading_form_viewed  mod_assign
# 4371412  888654310                 \core\event\course_viewed        core
# 4371413  888654310                 \core\event\course_viewed        core
#
#          action           target crud  edulevel  userid  courseid  \
# 4362998  viewed    course_module    r         2   17941     29855
# 4362999  viewed    course_module    r         2   17941     29855
# 4363000  viewed  submission_form    r         0   17941     29855
# 4363001  viewed  submission_form    r         0   17941     29855
# 4363002  viewed    course_module    r         2   17941     29855
# ...         ...              ...  ...       ...     ...       ...
# 4371288  viewed    grading_table    r         1   17941     29855
# 4371289  viewed     grading_form    r         1   17941     29855
# 4371290  viewed     grading_form    r         1   17941     29855
# 4371412  viewed           course    r         2   17941     29855
# 4371413  viewed           course    r         2   17941     29855
#
#                 timecreated
# 4362998 2023-04-04 15:00:53
# 4362999 2023-04-04 15:00:53
# 4363000 2023-04-04 15:00:54
# 4363001 2023-04-04 15:00:54
# 4363002 2023-04-04 15:04:22
# ...                     ...
# 4371288 2023-06-24 12:46:38
# 4371289 2023-06-24 12:46:40
# 4371290 2023-06-24 12:46:40
# 4371412 2023-06-25 08:29:36
# 4371413 2023-06-25 08:29:36
#
# [1286 rows x 10 columns]

# %% [markdown]
# ### Drop duplicates

# %%
df.drop_duplicates()
# Out:
#                 id                                 eventname     component  \
# 0        822218468     \core\event\course_user_report_viewed          core
# 1        822224558      \mod_quiz\event\course_module_viewed      mod_quiz
# 2        824242626                 \core\event\course_viewed          core
# 3        824242791  \mod_resource\event\course_module_viewed  mod_resource
# 4        824243066  \mod_resource\event\course_module_viewed  mod_resource
# ...            ...                                       ...           ...
# 6500584  888754296          \mod_quiz\event\attempt_reviewed      mod_quiz
# 6500585  888754317          \mod_quiz\event\attempt_reviewed      mod_quiz
# 6500586  888754326      \mod_quiz\event\course_module_viewed      mod_quiz
# 6500587  888754329          \mod_quiz\event\attempt_reviewed      mod_quiz
# 6500588  888754363          \mod_quiz\event\attempt_reviewed      mod_quiz
#
#            action              target crud  edulevel  userid  courseid  \
# 0          viewed  course_user_report    r         2   70580     30137
# 1          viewed       course_module    r         2   68637     30137
# 2          viewed              course    r         2   65908     30137
# 3          viewed       course_module    r         2   65908     30137
# 4          viewed       course_module    r         2   65908     30137
# ...           ...                 ...  ...       ...     ...       ...
# 6500584  reviewed             attempt    r         1   71305     34106
# 6500585  reviewed             attempt    r         1   71305     34106
# 6500586    viewed       course_module    r         2   71305     34106
# 6500587  reviewed             attempt    r         1   71305     34106
# 6500588  reviewed             attempt    r         1   71305     34106
#
#                 timecreated
# 0       2023-03-23 08:13:44
# 1       2023-03-23 08:22:48
# 2       2023-03-26 04:59:15
# 3       2023-03-26 04:59:47
# 4       2023-03-26 05:00:40
# ...                     ...
# 6500584 2023-06-25 16:52:41
# 6500585 2023-06-25 16:53:01
# 6500586 2023-06-25 16:53:08
# 6500587 2023-06-25 16:53:11
# 6500588 2023-06-25 16:53:43
#
# [6499946 rows x 10 columns]

# %% [markdown]
# ## Shortened the event name

# %%
shortened = list(value.split('\\')[1] + "\\" +  value.split('\\')[-1] for value in df["eventname"])
df["event"] = shortened
df
# Out:
#                 id                                 eventname     component  \
# 0        822218468     \core\event\course_user_report_viewed          core
# 1        822224558      \mod_quiz\event\course_module_viewed      mod_quiz
# 2        824242626                 \core\event\course_viewed          core
# 3        824242791  \mod_resource\event\course_module_viewed  mod_resource
# 4        824243066  \mod_resource\event\course_module_viewed  mod_resource
# ...            ...                                       ...           ...
# 6500584  888754296          \mod_quiz\event\attempt_reviewed      mod_quiz
# 6500585  888754317          \mod_quiz\event\attempt_reviewed      mod_quiz
# 6500586  888754326      \mod_quiz\event\course_module_viewed      mod_quiz
# 6500587  888754329          \mod_quiz\event\attempt_reviewed      mod_quiz
# 6500588  888754363          \mod_quiz\event\attempt_reviewed      mod_quiz
#
#            action              target crud  edulevel  userid  courseid  \
# 0          viewed  course_user_report    r         2   70580     30137
# 1          viewed       course_module    r         2   68637     30137
# 2          viewed              course    r         2   65908     30137
# 3          viewed       course_module    r         2   65908     30137
# 4          viewed       course_module    r         2   65908     30137
# ...           ...                 ...  ...       ...     ...       ...
# 6500584  reviewed             attempt    r         1   71305     34106
# 6500585  reviewed             attempt    r         1   71305     34106
# 6500586    viewed       course_module    r         2   71305     34106
# 6500587  reviewed             attempt    r         1   71305     34106
# 6500588  reviewed             attempt    r         1   71305     34106
#
#                 timecreated                              event
# 0       2023-03-23 08:13:44     core\course_user_report_viewed
# 1       2023-03-23 08:22:48      mod_quiz\course_module_viewed
# 2       2023-03-26 04:59:15                 core\course_viewed
# 3       2023-03-26 04:59:47  mod_resource\course_module_viewed
# 4       2023-03-26 05:00:40  mod_resource\course_module_viewed
# ...                     ...                                ...
# 6500584 2023-06-25 16:52:41          mod_quiz\attempt_reviewed
# 6500585 2023-06-25 16:53:01          mod_quiz\attempt_reviewed
# 6500586 2023-06-25 16:53:08      mod_quiz\course_module_viewed
# 6500587 2023-06-25 16:53:11          mod_quiz\attempt_reviewed
# 6500588 2023-06-25 16:53:43          mod_quiz\attempt_reviewed
#
# [6500589 rows x 11 columns]

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ### Distribution of Events Over Time

# %%
events_by_day = df.groupby(df['timecreated'].dt.date).size()

# %%
# PLot the distribution of events over time
plt.figure(figsize=(10, 6))
events_by_day.plot(kind='line', marker='o', color='b')
plt.title('Distribution of Events Over Time')
plt.xlabel('Date')
plt.ylabel('Number of Events')
plt.grid(True)
plt.xticks(rotation=45) # Rotate x-axis labels for better readability
plt.tight_layout()
plt.show()

# %%
# Filter data between two dates
filtered_df = df.loc[(df['timecreated'] < '2023-06-26')]

# %%
filtered_events_by_day = filtered_df.groupby(filtered_df['timecreated'].dt.date).size()

# %%
# PLot the distribution of events over time
plt.figure(figsize=(10, 6))
filtered_events_by_day.plot(kind='line', marker='o', color='b')
plt.title('Distribution of Events Over Time')
plt.xlabel('Date')
plt.ylabel('Number of Events')
plt.grid(True)
plt.xticks(rotation=45) # Rotate x-axis labels for better readability
plt.tight_layout()
plt.show()

# %%
# Group events by educational level and calculate the frequency of events for each level
events_by_edulevel = filtered_df.groupby('edulevel').size()

# %%
# Plot the distribution of events across different educational levels
plt.figure(figsize=(10, 6))
events_by_edulevel.plot(kind='bar', color='salmon')
plt.title('Distribution of Events Across Educational Levels')
plt.xlabel('Educational Level')
plt.ylabel('Frequency of Events')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Admin EDA

# %%
# Select the admin data
admin_df = filtered_df[filtered_df['edulevel'] == 0]
# admin_df

# %% [markdown]
# ### Count how many unique values in each column

# %%
for col in admin_df.columns:
    n = len(pd.unique(admin_df[col]))
    print("{:<20}: {:<}".format(col, n))
# Out:
# id                  : 625959
# eventname           : 40
# component           : 6
# action              : 9
# target              : 27
# crud                : 4
# edulevel            : 1
# userid              : 4585
# courseid            : 749
# timecreated         : 459627
# event               : 40

# %% [markdown]
# ### Events over time

# %%
admin_events_by_day = admin_df.groupby(admin_df['timecreated'].dt.date).size()

# %%
# Calculate the average number of events per day
average_events_per_day = admin_events_by_day.mean()

# PLot the distribution of events over time
plt.figure(figsize=(10, 6))
admin_events_by_day.plot(kind='line', marker='o', color='b')
plt.axhline(y=average_events_per_day, color='r', linestyle='--', label='Average Events per Day') # Add the average line
plt.title('Distribution of Events Over Time')
plt.xlabel('Date')
plt.ylabel('Number of Events')
plt.grid(True)
plt.xticks(rotation=45) # Rotate x-axis labels for better readability
plt.legend() # Show legend
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Top 5 and bottom 5 of event frequencies

# %%
event_counts = admin_df['event'].value_counts()

admin_top5_events = event_counts.head(5)
admin_bottom5_events = event_counts.tail(5)

# %%
admin_combined_events = pd.concat([admin_top5_events, admin_bottom5_events])

# %%
plt.figure(figsize=(12, 6))
bars = admin_combined_events.plot(kind='bar', color=['skyblue']*5 + ['salmon']*5)
plt.title('Top 5 and Bottom 5 Events by Frequency (Admin)')
plt.xlabel('Events')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.tight_layout()

for i, v in enumerate(admin_combined_events):
    bars.text(i, v + 0.2, str(v), ha='center', va='bottom')
    
plt.show()

# %%
plt.figure(figsize=(12, 6))
bars = admin_combined_events.plot(kind='bar', color=['skyblue']*5 + ['salmon']*5)
plt.title('Top 5 and Bottom 5 Events by Frequency (Admin)')
plt.xlabel('Events')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.tight_layout()

for i, v in enumerate(admin_combined_events):
    bars.text(i, v + 0.2, str(v), ha='center', va='bottom')
    
plt.show()

# %% [markdown]
# ### Top 5 and bottom 5 action

# %%
action_counts = admin_df['action'].value_counts()

admin_top5_actions = action_counts.head(5)
admin_bot5_actions = action_counts.tail(4)

# %%
admin_combined_actions = pd.concat([admin_top5_actions, admin_bot5_actions])

# %%
plt.figure(figsize=(12, 6))
bars = admin_combined_actions.plot(kind='bar', color=['skyblue']*5 + ['salmon']*5)
plt.title('Actions by Frequency (Admin)')
plt.xlabel('Actions')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.tight_layout()

for i, v in enumerate(admin_combined_actions):
    bars.text(i, v + 0.2, str(v), ha='center', va='bottom')

plt.show()

# %% [markdown]
# ### Top 5 and bottom 5 of components

# %%
component_counts = admin_df['component'].value_counts()

admin_top5_components = component_counts.head(4)
admin_bot5_components = component_counts.tail(3)

# %%
admin_combined_components = pd.concat([admin_top5_components, admin_bot5_components])

# %%
plt.figure(figsize=(12,6))
bars = admin_combined_components.plot(kind='bar', color=['skyblue']*5 + ['salmon']*5)
plt.title('Components by Frequency (Admin)')
plt.xlabel('Components')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.tight_layout()

for i, v in enumerate(admin_combined_components):
    bars.text(i, v + 0.2, str(v), ha='center', va='bottom')

plt.show()

# %% [markdown]
# ## Lecturer EDA

# %%
# Select the lecturer data
lecturer_df = filtered_df[filtered_df['edulevel'] == 1]
# lecturer_df

# %% [markdown]
# ### Count how many unique values in each column

# %%
for col in lecturer_df.columns:
    n = len(pd.unique(lecturer_df[col]))
    print("{:<20}: {:<}".format(col, n))
# Out:
# id                  : 497329
# eventname           : 63
# component           : 17
# action              : 16
# target              : 28
# crud                : 4
# edulevel            : 1
# userid              : 4191
# courseid            : 649
# timecreated         : 361450
# event               : 63

# %% [markdown]
# ### Events over time

# %%
lecturer_events_by_day = lecturer_df.groupby(lecturer_df['timecreated'].dt.date).size()

# %%
# Calculate the average number of events per day
average_events_per_day = lecturer_events_by_day.mean()

# PLot the distribution of events over time
plt.figure(figsize=(10, 6))
lecturer_events_by_day.plot(kind='line', marker='o', color='b')
plt.axhline(y=average_events_per_day, color='r', linestyle='--', label='Average Events per Day') # Add the average line
plt.title('Distribution of Events Over Time')
plt.xlabel('Date')
plt.ylabel('Number of Events')
plt.grid(True)
plt.xticks(rotation=45) # Rotate x-axis labels for better readability
plt.legend() # Show legend
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Top 5 and bottom 5 of event frequencies

# %%
event_counts = lecturer_df['event'].value_counts()

lecturer_top5_events = event_counts.head(5)
lecturer_bottom5_events = event_counts.tail(5)

# %%
lecturer_combined_events = pd.concat([lecturer_top5_events, lecturer_bottom5_events])

# %%
plt.figure(figsize=(12, 6))
bars = lecturer_combined_events.plot(kind='bar', color=['skyblue']*5 + ['salmon']*5)
plt.title('Top 5 and Bottom 5 Events by frequency (Lecturer)')
plt.xlabel('Events')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.tight_layout()

for i, v in enumerate(lecturer_combined_events):
    bars.text(i, v + 0.2, str(v), ha='center', va='bottom')

plt.show()

# %%
plt.figure(figsize=(12, 6))
bars = lecturer_combined_events.plot(kind='bar', color=['skyblue']*5 + ['salmon']*5)
plt.title('Top 5 and Bottom 5 Events by frequency (Lecturer)')
plt.xlabel('Events')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.tight_layout()

for i, v in enumerate(lecturer_combined_events):
    bars.text(i, v + 0.2, str(v), ha='center', va='bottom')

plt.show()

# %%
# Get the top 5 events
event_counts = lecturer_df['event'].value_counts()
lecturer_top5_events = event_counts.head(5).index

# Filter the dataframe to include only the top 5 events
top5_df = lecturer_df[lecturer_df['event'].isin(lecturer_top5_events)]

# Convert 'timecreated' to datetime if it's not already
top5_df['timecreated'] = pd.to_datetime(top5_df['timecreated'])

# Extract the date from 'timecreated'
top5_df['date'] = top5_df['timecreated'].dt.date

# Group by 'event' and 'date' and count occurrences
event_by_day = top5_df.groupby(['date', 'event']).size().unstack(fill_value=0)

# Plot the data
plt.figure(figsize=(12, 8))
for event in lecturer_top5_events:
    plt.plot(event_by_day.index, event_by_day[event], label=event)

plt.title('Top 5 Events by Day')
plt.xlabel('Date')
plt.ylabel('Count')
plt.legend(title='Event')
plt.grid(True)
plt.show()
# Out:
# C:\Users\sadli\AppData\Local\Temp\ipykernel_13168\3082429642.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top5_df['timecreated'] = pd.to_datetime(top5_df['timecreated'])
# C:\Users\sadli\AppData\Local\Temp\ipykernel_13168\3082429642.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top5_df['date'] = top5_df['timecreated'].dt.date

# %% [markdown]
# ### Top 5 and bottom 5 actions

# %%
action_counts = lecturer_df['action'].value_counts()

lecturer_top5_actions = action_counts.head(5)
lecturer_bot5_actions = action_counts.tail(5)

# %%
lecturer_combined_actions = pd.concat([lecturer_top5_actions, lecturer_bot5_actions])

# %%
plt.figure(figsize=(12, 6))
bars = lecturer_combined_actions.plot(kind='bar', color=['skyblue']*5 + ['salmon']*5)
plt.title('Actions by Frequency (Lecturer)')
plt.xlabel('Actions')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.tight_layout()

for i, v in enumerate(lecturer_combined_actions):
    bars.text(i, v + 0.2, str(v), ha='center', va='bottom')

plt.show()

# %% [markdown]
# ### Top 5 and Bottom 5 components

# %%
component_counts = lecturer_df['component'].value_counts()

lecturer_top5_components = component_counts.head(5)
lecturer_bot5_components = component_counts.tail(5)

# %%
lecturer_combined_components = pd.concat([lecturer_top5_components, lecturer_bot5_components])

# %%
plt.figure(figsize=(12, 6))
bars = lecturer_combined_components.plot(kind='bar', color=['skyblue']*5 + ['salmon']*5)
plt.title('Components by Frequency (Lecturer)')
plt.xlabel('Components')
plt.ylabel('Frequency')
plt.xticks(rotation=45)

for i, v in enumerate(lecturer_combined_components):
    bars.text(i, v + 0.2, str(v), ha='center', va='bottom')

plt.show()

# %% [markdown]
# ## Student EDA

# %%
# Select the student data
student_df = filtered_df[filtered_df['edulevel'] == 2]
# student_df

# %% [markdown]
# ### Check how manu unique values in each column

# %%
for col in student_df.columns:
    n = len(pd.unique(student_df[col]))
    print("{:<20}: {:<}".format(col, n))
# Out:
# id                  : 5311795
# eventname           : 62
# component           : 26
# action              : 13
# target              : 26
# crud                : 4
# edulevel            : 1
# userid              : 4665
# courseid            : 890
# timecreated         : 2575587
# event               : 62

# %% [markdown]
# ### Events over time

# %%
student_events_by_day = student_df.groupby(student_df['timecreated'].dt.date).size()

# %%
# Calculate the average number of events per day
average_events_per_day = student_events_by_day.mean()

# PLot the distribution of events over time
plt.figure(figsize=(10, 6))
student_events_by_day.plot(kind='line', marker='o', color='b')
plt.axhline(y=average_events_per_day, color='r', linestyle='--', label='Average Events per Day') # Add the average line
plt.title('Distribution of Events Over Time')
plt.xlabel('Date')
plt.ylabel('Number of Events')
plt.grid(True)
plt.xticks(rotation=45) # Rotate x-axis labels for better readability
plt.legend() # Show legend
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Top 5 and bottom 5 of events frequencies

# %%
event_counts = student_df['event'].value_counts()

student_top5_events = event_counts.head(5)
student_bottom5_events = event_counts.tail(5)

# %%
student_combined_events = pd.concat([student_top5_events, student_bottom5_events])

# %%
plt.figure(figsize=(12, 6))
bars = student_combined_events.plot(kind='bar', color=['skyblue']*5 + ['salmon']*5)
plt.title('Top 5 and Bottom 5 Event by frequency (Student)')
plt.xlabel('Events')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.tight_layout()

for i, v in enumerate(student_combined_events):
    bars.text(i, v + 0.2, str(v), ha='center', va='bottom')

plt.show()

# %%
plt.figure(figsize=(12, 6))
bars = student_combined_events.plot(kind='bar', color=['skyblue']*5 + ['salmon']*5)
plt.title('Top 5 and Bottom 5 Event by frequency (Student)')
plt.xlabel('Events')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.tight_layout()

for i, v in enumerate(student_combined_events):
    bars.text(i, v + 0.2, str(v), ha='center', va='bottom')

plt.show()

# %%
# Get the top 5 events
event_counts = student_df['event'].value_counts()
student_top5_events = event_counts.head(5).index

# Filter the dataframe to include only the top 5 events
top5_df = student_df[student_df['event'].isin(student_top5_events)]

# Convert 'timecreated' to datetime if it's not already
top5_df['timecreated'] = pd.to_datetime(top5_df['timecreated'])

# Extract the date from 'timecreated'
top5_df['date'] = top5_df['timecreated'].dt.date

# Group by 'event' and 'date' and count occurrences
event_by_day = top5_df.groupby(['date', 'event']).size().unstack(fill_value=0)

# Plot the data
plt.figure(figsize=(12, 8))
for event in student_top5_events:
    plt.plot(event_by_day.index, event_by_day[event], label=event)

plt.title('Top 5 Events by Day')
plt.xlabel('Date')
plt.ylabel('Count')
plt.legend(title='Event')
plt.grid(True)
plt.show()
# Out:
# C:\Users\sadli\AppData\Local\Temp\ipykernel_13168\3445429130.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top5_df['timecreated'] = pd.to_datetime(top5_df['timecreated'])
# C:\Users\sadli\AppData\Local\Temp\ipykernel_13168\3445429130.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top5_df['date'] = top5_df['timecreated'].dt.date

# %% [markdown]
# ### Top 5 and Bottom 5 action

# %%
action_counts = student_df['action'].value_counts()

student_top5_actions = action_counts.head(5)
student_bot5_actions = action_counts.tail(5)

# %%
student_combined_actions = pd.concat([student_top5_actions, student_bot5_actions])

# %%
plt.figure(figsize=(12, 6))
bars = student_combined_actions.plot(kind='bar', color=['skyblue']*5 + ['salmon']*5)
plt.title('Actions by Frequency (Student)')
plt.xlabel('Actions')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.tight_layout()

for i, v in enumerate(student_combined_actions):
    bars.text(i, v + 0.2, str(v), ha='center', va='bottom')

plt.show()

# %% [markdown]
# ### Top 5 and Bottom 5 of Components

# %%
component_counts = student_df['component'].value_counts()

student_top5_components = component_counts.head(5)
student_bot5_components = component_counts.tail(5)

# %%
student_combined_components = pd.concat([student_top5_components, student_bot5_components])

# %%
plt.figure(figsize=(12, 6))
bars = student_combined_components.plot(kind='bar', color=['skyblue']*5 + ['salmon']*5)
plt.title('Components by Frequency (Student)')
plt.xlabel('Components')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.tight_layout()

for i, v in enumerate(student_combined_components):
    bars.text(i, v + 0.2, str(v), ha='center', va='bottom')

plt.show()

# %%
lecturer_df.to_csv('../../cleaned_dataset/Lecturer/FRI_Lecturer.csv')
student_df.to_csv('../../cleaned_dataset/Student/FRI_Student.csv')

# %%
# %reset -f
