# %%
import pandas as pd

# %% [markdown]
# ## Reading dataset and check the info

# %%
df = pd.read_csv("../../dataset/All/22232-FIK.csv")

# %%
df
# Out:
#                  id                               eventname   component  \
# 0         820797547               \core\event\course_viewed        core
# 1         821346953               \core\event\course_viewed        core
# 2         821347275     \mod_url\event\course_module_viewed     mod_url
# 3         821347322               \core\event\course_viewed        core
# 4         821347566     \mod_url\event\course_module_viewed     mod_url
# ...             ...                                     ...         ...
# 3656653  1062496378  \mod_assign\event\grading_table_viewed  mod_assign
# 3656654  1062496396   \mod_assign\event\grading_form_viewed  mod_assign
# 3656655  1062496681  \mod_assign\event\course_module_viewed  mod_assign
# 3656656  1062496682  \mod_assign\event\grading_table_viewed  mod_assign
# 3656657  1062496704   \mod_assign\event\grading_form_viewed  mod_assign
#
#          action         target objecttable  objectid crud  edulevel  \
# 0        viewed         course         NaN       NaN    r         2
# 1        viewed         course         NaN       NaN    r         2
# 2        viewed  course_module         url  696635.0    r         2
# 3        viewed         course         NaN       NaN    r         2
# 4        viewed  course_module         url  696633.0    r         2
# ...         ...            ...         ...       ...  ...       ...
# 3656653  viewed  grading_table         NaN       NaN    r         1
# 3656654  viewed   grading_form         NaN       NaN    r         1
# 3656655  viewed  course_module      assign  389718.0    r         2
# 3656656  viewed  grading_table         NaN       NaN    r         1
# 3656657  viewed   grading_form         NaN       NaN    r         1
#
#          contextid  ...  contextinstanceid  userid  courseid  relateduserid  \
# 0          3634766  ...              29936   72581     29936            NaN
# 1          3634766  ...              29936   20528     29936            NaN
# 2          4011559  ...            3094567   20528     29936            NaN
# 3          3634766  ...              29936   20528     29936            NaN
# 4          4011557  ...            3094565   20528     29936            NaN
# ...            ...  ...                ...     ...       ...            ...
# 3656653    3985529  ...            3068676   42702     34513            NaN
# 3656654    3985529  ...            3068676   42702     34513        56476.0
# 3656655    3985529  ...            3068676   42702     34513            NaN
# 3656656    3985529  ...            3068676   42702     34513            NaN
# 3656657    3985529  ...            3068676   42702     34513        56087.0
#
#          anonymous                               other timecreated  origin  \
# 0                0                                  N;  1679379618     web
# 1                0                                  N;  1679416084     web
# 2                0                                  N;  1679416119     web
# 3                0                                  N;  1679416123     web
# 4                0                                  N;  1679416144     web
# ...            ...                                 ...         ...     ...
# 3656653          0  a:1:{s:8:"assignid";s:6:"389718";}  1710743078     web
# 3656654          0  a:1:{s:8:"assignid";s:6:"389718";}  1710743079     web
# 3656655          0                                  N;  1710743099     web
# 3656656          0  a:1:{s:8:"assignid";s:6:"389718";}  1710743099     web
# 3656657          0  a:1:{s:8:"assignid";s:6:"389718";}  1710743100     web
#
#                       ip realuserid
# 0           36.69.198.23        NaN
# 1         103.194.175.70        NaN
# 2         103.194.175.70        NaN
# 3         103.194.175.70        NaN
# 4         103.194.175.70        NaN
# ...                  ...        ...
# 3656653  103.233.100.229        NaN
# 3656654  103.233.100.229        NaN
# 3656655  103.233.100.229        NaN
# 3656656  103.233.100.229        NaN
# 3656657  103.233.100.229        NaN
#
# [3656658 rows x 21 columns]

# %%
df.shape
# Out:
# (3656658, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3656658 entries, 0 to 3656657
# Data columns (total 21 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   id                 int64
#  1   eventname          object
#  2   component          object
#  3   action             object
#  4   target             object
#  5   objecttable        object
#  6   objectid           float64
#  7   crud               object
#  8   edulevel           int64
#  9   contextid          int64
#  10  contextlevel       int64
#  11  contextinstanceid  int64
#  12  userid             int64
#  13  courseid           int64
#  14  relateduserid      float64
#  15  anonymous          int64
#  16  other              object
#  17  timecreated        int64
#  18  origin             object
#  19  ip                 object
#  20  realuserid         float64
# dtypes: float64(3), int64(9), object(9)
# memory usage: 585.9+ MB

# %% [markdown]
# ## Count unique values in each column

# %%
for col in df.columns:
    n = len(pd.unique(df[col]))
    print("{:<20}: {:<}".format(col, n))
# Out:
# id                  : 3656440
# eventname           : 152
# component           : 40
# action              : 26
# target              : 68
# objecttable         : 51
# objectid            : 720802
# crud                : 4
# edulevel            : 3
# contextid           : 50994
# contextlevel        : 2
# contextinstanceid   : 50994
# userid              : 4118
# courseid            : 904
# relateduserid       : 4042
# anonymous           : 2
# other               : 272809
# timecreated         : 1943422
# origin              : 4
# ip                  : 43920
# realuserid          : 1

# %% [markdown]
# ## Check if there is null values

# %%
df.isnull().sum()
# Out:
# id                         0
# eventname                  0
# component                  0
# action                     0
# target                     0
# objecttable          1185877
# objectid             1185877
# crud                       0
# edulevel                   0
# contextid                  0
# contextlevel               0
# contextinstanceid          0
# userid                     0
# courseid                   0
# relateduserid        2290761
# anonymous                  0
# other                      0
# timecreated                0
# origin                     0
# ip                     14437
# realuserid           3656658
# dtype: int64

# %% [markdown]
# ## Change time from epoch to datetime

# %% [markdown]
# ### Convert the time to datetime

# %%
df['timecreated'] = pd.to_datetime(df['timecreated'], unit='s')
df
# Out:
#                  id                               eventname   component  \
# 0         820797547               \core\event\course_viewed        core
# 1         821346953               \core\event\course_viewed        core
# 2         821347275     \mod_url\event\course_module_viewed     mod_url
# 3         821347322               \core\event\course_viewed        core
# 4         821347566     \mod_url\event\course_module_viewed     mod_url
# ...             ...                                     ...         ...
# 3656653  1062496378  \mod_assign\event\grading_table_viewed  mod_assign
# 3656654  1062496396   \mod_assign\event\grading_form_viewed  mod_assign
# 3656655  1062496681  \mod_assign\event\course_module_viewed  mod_assign
# 3656656  1062496682  \mod_assign\event\grading_table_viewed  mod_assign
# 3656657  1062496704   \mod_assign\event\grading_form_viewed  mod_assign
#
#          action         target objecttable  objectid crud  edulevel  \
# 0        viewed         course         NaN       NaN    r         2
# 1        viewed         course         NaN       NaN    r         2
# 2        viewed  course_module         url  696635.0    r         2
# 3        viewed         course         NaN       NaN    r         2
# 4        viewed  course_module         url  696633.0    r         2
# ...         ...            ...         ...       ...  ...       ...
# 3656653  viewed  grading_table         NaN       NaN    r         1
# 3656654  viewed   grading_form         NaN       NaN    r         1
# 3656655  viewed  course_module      assign  389718.0    r         2
# 3656656  viewed  grading_table         NaN       NaN    r         1
# 3656657  viewed   grading_form         NaN       NaN    r         1
#
#          contextid  ...  contextinstanceid  userid  courseid  relateduserid  \
# 0          3634766  ...              29936   72581     29936            NaN
# 1          3634766  ...              29936   20528     29936            NaN
# 2          4011559  ...            3094567   20528     29936            NaN
# 3          3634766  ...              29936   20528     29936            NaN
# 4          4011557  ...            3094565   20528     29936            NaN
# ...            ...  ...                ...     ...       ...            ...
# 3656653    3985529  ...            3068676   42702     34513            NaN
# 3656654    3985529  ...            3068676   42702     34513        56476.0
# 3656655    3985529  ...            3068676   42702     34513            NaN
# 3656656    3985529  ...            3068676   42702     34513            NaN
# 3656657    3985529  ...            3068676   42702     34513        56087.0
#
#          anonymous                               other         timecreated  \
# 0                0                                  N; 2023-03-21 06:20:18
# 1                0                                  N; 2023-03-21 16:28:04
# 2                0                                  N; 2023-03-21 16:28:39
# 3                0                                  N; 2023-03-21 16:28:43
# 4                0                                  N; 2023-03-21 16:29:04
# ...            ...                                 ...                 ...
# 3656653          0  a:1:{s:8:"assignid";s:6:"389718";} 2024-03-18 06:24:38
# 3656654          0  a:1:{s:8:"assignid";s:6:"389718";} 2024-03-18 06:24:39
# 3656655          0                                  N; 2024-03-18 06:24:59
# 3656656          0  a:1:{s:8:"assignid";s:6:"389718";} 2024-03-18 06:24:59
# 3656657          0  a:1:{s:8:"assignid";s:6:"389718";} 2024-03-18 06:25:00
#
#         origin               ip realuserid
# 0          web     36.69.198.23        NaN
# 1          web   103.194.175.70        NaN
# 2          web   103.194.175.70        NaN
# 3          web   103.194.175.70        NaN
# 4          web   103.194.175.70        NaN
# ...        ...              ...        ...
# 3656653    web  103.233.100.229        NaN
# 3656654    web  103.233.100.229        NaN
# 3656655    web  103.233.100.229        NaN
# 3656656    web  103.233.100.229        NaN
# 3656657    web  103.233.100.229        NaN
#
# [3656658 rows x 21 columns]

# %% [markdown]
# ### Check the range of the dataset

# %%
# Find the minimum and maximum dates
min_date = df['timecreated'].min()
max_date = df['timecreated'].max()

print('Minimum date:', min_date)
print('Maximum date:', max_date)
# Out:
# Minimum date: 2023-03-21 04:23:14
# Maximum date: 2024-03-20 03:47:28

# %% [markdown]
# ## Remove uneccessary columns

# %%
df = df.drop(columns = ['objecttable', 'objectid', 'contextid', 
                         'contextlevel', 'contextinstanceid', 'relateduserid',
                         'anonymous', 'other', 'origin', 'ip', 'realuserid'])
df
# Out:
#                  id                               eventname   component  \
# 0         820797547               \core\event\course_viewed        core
# 1         821346953               \core\event\course_viewed        core
# 2         821347275     \mod_url\event\course_module_viewed     mod_url
# 3         821347322               \core\event\course_viewed        core
# 4         821347566     \mod_url\event\course_module_viewed     mod_url
# ...             ...                                     ...         ...
# 3656653  1062496378  \mod_assign\event\grading_table_viewed  mod_assign
# 3656654  1062496396   \mod_assign\event\grading_form_viewed  mod_assign
# 3656655  1062496681  \mod_assign\event\course_module_viewed  mod_assign
# 3656656  1062496682  \mod_assign\event\grading_table_viewed  mod_assign
# 3656657  1062496704   \mod_assign\event\grading_form_viewed  mod_assign
#
#          action         target crud  edulevel  userid  courseid  \
# 0        viewed         course    r         2   72581     29936
# 1        viewed         course    r         2   20528     29936
# 2        viewed  course_module    r         2   20528     29936
# 3        viewed         course    r         2   20528     29936
# 4        viewed  course_module    r         2   20528     29936
# ...         ...            ...  ...       ...     ...       ...
# 3656653  viewed  grading_table    r         1   42702     34513
# 3656654  viewed   grading_form    r         1   42702     34513
# 3656655  viewed  course_module    r         2   42702     34513
# 3656656  viewed  grading_table    r         1   42702     34513
# 3656657  viewed   grading_form    r         1   42702     34513
#
#                 timecreated
# 0       2023-03-21 06:20:18
# 1       2023-03-21 16:28:04
# 2       2023-03-21 16:28:39
# 3       2023-03-21 16:28:43
# 4       2023-03-21 16:29:04
# ...                     ...
# 3656653 2024-03-18 06:24:38
# 3656654 2024-03-18 06:24:39
# 3656655 2024-03-18 06:24:59
# 3656656 2024-03-18 06:24:59
# 3656657 2024-03-18 06:25:00
#
# [3656658 rows x 10 columns]

# %%
df.isnull().sum()
# Out:
# id             0
# eventname      0
# component      0
# action         0
# target         0
# crud           0
# edulevel       0
# userid         0
# courseid       0
# timecreated    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3656658 entries, 0 to 3656657
# Data columns (total 10 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   id           int64
#  1   eventname    object
#  2   component    object
#  3   action       object
#  4   target       object
#  5   crud         object
#  6   edulevel     int64
#  7   userid       int64
#  8   courseid     int64
#  9   timecreated  datetime64[ns]
# dtypes: datetime64[ns](1), int64(4), object(5)
# memory usage: 279.0+ MB

# %% [markdown]
# ## Check if there is duplicates data and remove it

# %% [markdown]
# ### Check for duplicates

# %%
duplicate_mask = df.duplicated(keep=False)

duplicate_rows = df[duplicate_mask]
duplicate_rows
# Out:
#                 id                               eventname   component  \
# 2104866  830552475               \core\event\course_viewed        core
# 2104867  830552475               \core\event\course_viewed        core
# 2104868  831474680               \core\event\course_viewed        core
# 2104869  831474680               \core\event\course_viewed        core
# 2104978  840150155  \mod_assign\event\course_module_viewed  mod_assign
# ...            ...                                     ...         ...
# 2133401  887758955  \mod_assign\event\grading_table_viewed  mod_assign
# 2133402  887759118  \mod_assign\event\course_module_viewed  mod_assign
# 2133403  887759118  \mod_assign\event\course_module_viewed  mod_assign
# 2133404  887759119  \mod_assign\event\grading_table_viewed  mod_assign
# 2133405  887759119  \mod_assign\event\grading_table_viewed  mod_assign
#
#          action         target crud  edulevel  userid  courseid  \
# 2104866  viewed         course    r         2   36409     33867
# 2104867  viewed         course    r         2   36409     33867
# 2104868  viewed         course    r         2   36409     33867
# 2104869  viewed         course    r         2   36409     33867
# 2104978  viewed  course_module    r         2   36409     33867
# ...         ...            ...  ...       ...     ...       ...
# 2133401  viewed  grading_table    r         1   71282     33875
# 2133402  viewed  course_module    r         2   71282     33875
# 2133403  viewed  course_module    r         2   71282     33875
# 2133404  viewed  grading_table    r         1   71282     33875
# 2133405  viewed  grading_table    r         1   71282     33875
#
#                 timecreated
# 2104866 2023-04-03 04:28:21
# 2104867 2023-04-03 04:28:21
# 2104868 2023-04-04 04:45:45
# 2104869 2023-04-04 04:45:45
# 2104978 2023-04-13 05:00:43
# ...                     ...
# 2133401 2023-06-23 12:23:56
# 2133402 2023-06-23 12:24:18
# 2133403 2023-06-23 12:24:18
# 2133404 2023-06-23 12:24:18
# 2133405 2023-06-23 12:24:18
#
# [436 rows x 10 columns]

# %% [markdown]
# ### Drop duplicates

# %%
df.drop_duplicates()
# Out:
#                  id                               eventname   component  \
# 0         820797547               \core\event\course_viewed        core
# 1         821346953               \core\event\course_viewed        core
# 2         821347275     \mod_url\event\course_module_viewed     mod_url
# 3         821347322               \core\event\course_viewed        core
# 4         821347566     \mod_url\event\course_module_viewed     mod_url
# ...             ...                                     ...         ...
# 3656653  1062496378  \mod_assign\event\grading_table_viewed  mod_assign
# 3656654  1062496396   \mod_assign\event\grading_form_viewed  mod_assign
# 3656655  1062496681  \mod_assign\event\course_module_viewed  mod_assign
# 3656656  1062496682  \mod_assign\event\grading_table_viewed  mod_assign
# 3656657  1062496704   \mod_assign\event\grading_form_viewed  mod_assign
#
#          action         target crud  edulevel  userid  courseid  \
# 0        viewed         course    r         2   72581     29936
# 1        viewed         course    r         2   20528     29936
# 2        viewed  course_module    r         2   20528     29936
# 3        viewed         course    r         2   20528     29936
# 4        viewed  course_module    r         2   20528     29936
# ...         ...            ...  ...       ...     ...       ...
# 3656653  viewed  grading_table    r         1   42702     34513
# 3656654  viewed   grading_form    r         1   42702     34513
# 3656655  viewed  course_module    r         2   42702     34513
# 3656656  viewed  grading_table    r         1   42702     34513
# 3656657  viewed   grading_form    r         1   42702     34513
#
#                 timecreated
# 0       2023-03-21 06:20:18
# 1       2023-03-21 16:28:04
# 2       2023-03-21 16:28:39
# 3       2023-03-21 16:28:43
# 4       2023-03-21 16:29:04
# ...                     ...
# 3656653 2024-03-18 06:24:38
# 3656654 2024-03-18 06:24:39
# 3656655 2024-03-18 06:24:59
# 3656656 2024-03-18 06:24:59
# 3656657 2024-03-18 06:25:00
#
# [3656440 rows x 10 columns]

# %% [markdown]
# ## Shortened the event name

# %%
shortened = list(value.split('\\')[1] + "\\" +  value.split('\\')[-1] for value in df["eventname"])
df["event"] = shortened
df
# Out:
#                  id                               eventname   component  \
# 0         820797547               \core\event\course_viewed        core
# 1         821346953               \core\event\course_viewed        core
# 2         821347275     \mod_url\event\course_module_viewed     mod_url
# 3         821347322               \core\event\course_viewed        core
# 4         821347566     \mod_url\event\course_module_viewed     mod_url
# ...             ...                                     ...         ...
# 3656653  1062496378  \mod_assign\event\grading_table_viewed  mod_assign
# 3656654  1062496396   \mod_assign\event\grading_form_viewed  mod_assign
# 3656655  1062496681  \mod_assign\event\course_module_viewed  mod_assign
# 3656656  1062496682  \mod_assign\event\grading_table_viewed  mod_assign
# 3656657  1062496704   \mod_assign\event\grading_form_viewed  mod_assign
#
#          action         target crud  edulevel  userid  courseid  \
# 0        viewed         course    r         2   72581     29936
# 1        viewed         course    r         2   20528     29936
# 2        viewed  course_module    r         2   20528     29936
# 3        viewed         course    r         2   20528     29936
# 4        viewed  course_module    r         2   20528     29936
# ...         ...            ...  ...       ...     ...       ...
# 3656653  viewed  grading_table    r         1   42702     34513
# 3656654  viewed   grading_form    r         1   42702     34513
# 3656655  viewed  course_module    r         2   42702     34513
# 3656656  viewed  grading_table    r         1   42702     34513
# 3656657  viewed   grading_form    r         1   42702     34513
#
#                 timecreated                            event
# 0       2023-03-21 06:20:18               core\course_viewed
# 1       2023-03-21 16:28:04               core\course_viewed
# 2       2023-03-21 16:28:39     mod_url\course_module_viewed
# 3       2023-03-21 16:28:43               core\course_viewed
# 4       2023-03-21 16:29:04     mod_url\course_module_viewed
# ...                     ...                              ...
# 3656653 2024-03-18 06:24:38  mod_assign\grading_table_viewed
# 3656654 2024-03-18 06:24:39   mod_assign\grading_form_viewed
# 3656655 2024-03-18 06:24:59  mod_assign\course_module_viewed
# 3656656 2024-03-18 06:24:59  mod_assign\grading_table_viewed
# 3656657 2024-03-18 06:25:00   mod_assign\grading_form_viewed
#
# [3656658 rows x 11 columns]

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ### Distribution of Events Over Time

# %%
events_by_day = df.groupby(df['timecreated'].dt.date).size()

# %%
# PLot the distribution of events over time
plt.figure(figsize=(10, 6))
events_by_day.plot(kind='line', marker='o', color='b')
plt.title('Distribution of Events Over Time')
plt.xlabel('Date')
plt.ylabel('Number of Events')
plt.grid(True)
plt.xticks(rotation=45) # Rotate x-axis labels for better readability
plt.tight_layout()
plt.show()

# %%
# Filter data between two dates
filtered_df = df.loc[(df['timecreated'] < '2023-06-26')]

# %%
filtered_events_by_day = filtered_df.groupby(filtered_df['timecreated'].dt.date).size()

# %%
# PLot the distribution of events over time
plt.figure(figsize=(10, 6))
filtered_events_by_day.plot(kind='line', marker='o', color='b')
plt.title('Distribution of Events Over Time')
plt.xlabel('Date')
plt.ylabel('Number of Events')
plt.grid(True)
plt.xticks(rotation=45) # Rotate x-axis labels for better readability
plt.tight_layout()
plt.show()

# %%
# Group events by educational level and calculate the frequency of events for each level
events_by_edulevel = filtered_df.groupby('edulevel').size()

# %%
# Plot the distribution of events across different educational levels
plt.figure(figsize=(10, 6))
events_by_edulevel.plot(kind='bar', color='salmon')
plt.title('Distribution of Events Across Educational Levels')
plt.xlabel('Educational Level')
plt.ylabel('Frequency of Events')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Admin EDA

# %%
# Select the admin data
admin_df = filtered_df[filtered_df['edulevel'] == 0]
# admin_df

# %% [markdown]
# ### Count how many unique values in each column

# %%
for col in admin_df.columns:
    n = len(pd.unique(admin_df[col]))
    print("{:<20}: {:<}".format(col, n))
# Out:
# id                  : 570594
# eventname           : 35
# component           : 8
# action              : 9
# target              : 24
# crud                : 4
# edulevel            : 1
# userid              : 3942
# courseid            : 848
# timecreated         : 487430
# event               : 35

# %% [markdown]
# ### Events over time

# %%
admin_events_by_day = admin_df.groupby(admin_df['timecreated'].dt.date).size()

# %%
# Calculate the average number of events per day
average_events_per_day = admin_events_by_day.mean()

# PLot the distribution of events over time
plt.figure(figsize=(10, 6))
admin_events_by_day.plot(kind='line', marker='o', color='b')
plt.axhline(y=average_events_per_day, color='r', linestyle='--', label='Average Events per Day') # Add the average line
plt.title('Distribution of Events Over Time')
plt.xlabel('Date')
plt.ylabel('Number of Events')
plt.grid(True)
plt.xticks(rotation=45) # Rotate x-axis labels for better readability
plt.legend() # Show legend
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Top 5 and bottom 5 of event frequencies

# %%
event_counts = admin_df['event'].value_counts()

admin_top5_events = event_counts.head(5)
admin_bottom5_events = event_counts.tail(5)

# %%
admin_combined_events = pd.concat([admin_top5_events, admin_bottom5_events])

# %%
plt.figure(figsize=(12, 6))
bars = admin_combined_events.plot(kind='bar', color=['skyblue']*5 + ['salmon']*5)
plt.title('Top 5 and Bottom 5 Events by Frequency (Admin)')
plt.xlabel('Events')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.tight_layout()

for i, v in enumerate(admin_combined_events):
    bars.text(i, v + 0.2, str(v), ha='center', va='bottom')
    
plt.show()

# %% [markdown]
# ### Top 5 and bottom 5 action

# %%
action_counts = admin_df['action'].value_counts()

admin_top5_actions = action_counts.head(5)
admin_bot5_actions = action_counts.tail(4)

# %%
admin_combined_actions = pd.concat([admin_top5_actions, admin_bot5_actions])

# %%
plt.figure(figsize=(12, 6))
bars = admin_combined_actions.plot(kind='bar', color=['skyblue']*5 + ['salmon']*5)
plt.title('Actions by Frequency (Admin)')
plt.xlabel('Actions')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.tight_layout()

for i, v in enumerate(admin_combined_actions):
    bars.text(i, v + 0.2, str(v), ha='center', va='bottom')

plt.show()

# %% [markdown]
# ### Top 5 and bottom 5 of components

# %%
component_counts = admin_df['component'].value_counts()

admin_top5_components = component_counts.head(4)
admin_bot5_components = component_counts.tail(3)

# %%
admin_combined_components = pd.concat([admin_top5_components, admin_bot5_components])

# %%
plt.figure(figsize=(12,6))
bars = admin_combined_components.plot(kind='bar', color=['skyblue']*5 + ['salmon']*5)
plt.title('Components by Frequency (Admin)')
plt.xlabel('Components')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.tight_layout()

for i, v in enumerate(admin_combined_components):
    bars.text(i, v + 0.2, str(v), ha='center', va='bottom')

plt.show()

# %% [markdown]
# ## Lecturer EDA

# %%
# Select the lecturer data
lecturer_df = filtered_df[filtered_df['edulevel'] == 1]
# lecturer_df

# %% [markdown]
# ### Count how many unique values in each column

# %%
for col in lecturer_df.columns:
    n = len(pd.unique(lecturer_df[col]))
    print("{:<20}: {:<}".format(col, n))
# Out:
# id                  : 280886
# eventname           : 52
# component           : 14
# action              : 16
# target              : 27
# crud                : 4
# edulevel            : 1
# userid              : 3407
# courseid            : 787
# timecreated         : 214745
# event               : 52

# %% [markdown]
# ### Events over time

# %%
lecturer_events_by_day = lecturer_df.groupby(lecturer_df['timecreated'].dt.date).size()

# %%
# Calculate the average number of events per day
average_events_per_day = lecturer_events_by_day.mean()

# PLot the distribution of events over time
plt.figure(figsize=(10, 6))
lecturer_events_by_day.plot(kind='line', marker='o', color='b')
plt.axhline(y=average_events_per_day, color='r', linestyle='--', label='Average Events per Day') # Add the average line
plt.title('Distribution of Events Over Time')
plt.xlabel('Date')
plt.ylabel('Number of Events')
plt.grid(True)
plt.xticks(rotation=45) # Rotate x-axis labels for better readability
plt.legend() # Show legend
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Top 5 and bottom 5 of event frequencies

# %%
event_counts = lecturer_df['event'].value_counts()

lecturer_top5_events = event_counts.head(5)
lecturer_bottom5_events = event_counts.tail(5)

# %%
lecturer_combined_events = pd.concat([lecturer_top5_events, lecturer_bottom5_events])

# %%
plt.figure(figsize=(12, 6))
bars = lecturer_combined_events.plot(kind='bar', color=['skyblue']*5 + ['salmon']*5)
plt.title('Top 5 and Bottom 5 Events by frequency (Lecturer)')
plt.xlabel('Events')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.tight_layout()

for i, v in enumerate(lecturer_combined_events):
    bars.text(i, v + 0.2, str(v), ha='center', va='bottom')

plt.show()

# %%
plt.figure(figsize=(12, 6))
bars = lecturer_combined_events.plot(kind='bar', color=['skyblue']*5 + ['salmon']*5)
plt.title('Top 5 and Bottom 5 Events by frequency (Lecturer)')
plt.xlabel('Events')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.tight_layout()

for i, v in enumerate(lecturer_combined_events):
    bars.text(i, v + 0.2, str(v), ha='center', va='bottom')

plt.show()

# %%
# Get the top 5 events
event_counts = lecturer_df['event'].value_counts()
lecturer_top5_events = event_counts.head(5).index

# Filter the dataframe to include only the top 5 events
top5_df = lecturer_df[lecturer_df['event'].isin(lecturer_top5_events)]

# Convert 'timecreated' to datetime if it's not already
top5_df['timecreated'] = pd.to_datetime(top5_df['timecreated'])

# Extract the date from 'timecreated'
top5_df['date'] = top5_df['timecreated'].dt.date

# Group by 'event' and 'date' and count occurrences
event_by_day = top5_df.groupby(['date', 'event']).size().unstack(fill_value=0)

# Plot the data
plt.figure(figsize=(12, 8))
for event in lecturer_top5_events:
    plt.plot(event_by_day.index, event_by_day[event], label=event)

plt.title('Top 5 Events by Day')
plt.xlabel('Date')
plt.ylabel('Count')
plt.legend(title='Event')
plt.grid(True)
plt.show()
# Out:
# C:\Users\sadli\AppData\Local\Temp\ipykernel_4968\3082429642.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top5_df['timecreated'] = pd.to_datetime(top5_df['timecreated'])
# C:\Users\sadli\AppData\Local\Temp\ipykernel_4968\3082429642.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top5_df['date'] = top5_df['timecreated'].dt.date

# %% [markdown]
# ### Top 5 and bottom 5 actions

# %%
action_counts = lecturer_df['action'].value_counts()

lecturer_top5_actions = action_counts.head(5)
lecturer_bot5_actions = action_counts.tail(5)

# %%
lecturer_combined_actions = pd.concat([lecturer_top5_actions, lecturer_bot5_actions])

# %%
plt.figure(figsize=(12, 6))
bars = lecturer_combined_actions.plot(kind='bar', color=['skyblue']*5 + ['salmon']*5)
plt.title('Actions by Frequency (Lecturer)')
plt.xlabel('Actions')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.tight_layout()

for i, v in enumerate(lecturer_combined_actions):
    bars.text(i, v + 0.2, str(v), ha='center', va='bottom')

plt.show()

# %% [markdown]
# ### Top 5 and Bottom 5 components

# %%
component_counts = lecturer_df['component'].value_counts()

lecturer_top5_components = component_counts.head(5)
lecturer_bot5_components = component_counts.tail(5)

# %%
lecturer_combined_components = pd.concat([lecturer_top5_components, lecturer_bot5_components])

# %%
plt.figure(figsize=(12, 6))
bars = lecturer_combined_components.plot(kind='bar', color=['skyblue']*5 + ['salmon']*5)
plt.title('Components by Frequency (Lecturer)')
plt.xlabel('Components')
plt.ylabel('Frequency')
plt.xticks(rotation=45)

for i, v in enumerate(lecturer_combined_components):
    bars.text(i, v + 0.2, str(v), ha='center', va='bottom')

plt.show()

# %% [markdown]
# ## Student EDA

# %%
# Select the student data
student_df = filtered_df[filtered_df['edulevel'] == 2]
# student_df

# %% [markdown]
# ### Check how manu unique values in each column

# %%
for col in student_df.columns:
    n = len(pd.unique(student_df[col]))
    print("{:<20}: {:<}".format(col, n))
# Out:
# id                  : 2786128
# eventname           : 64
# component           : 26
# action              : 11
# target              : 27
# crud                : 4
# edulevel            : 1
# userid              : 4091
# courseid            : 902
# timecreated         : 1759530
# event               : 64

# %% [markdown]
# ### Events over time

# %%
student_events_by_day = student_df.groupby(student_df['timecreated'].dt.date).size()

# %%
# Calculate the average number of events per day
average_events_per_day = student_events_by_day.mean()

# PLot the distribution of events over time
plt.figure(figsize=(10, 6))
student_events_by_day.plot(kind='line', marker='o', color='b')
plt.axhline(y=average_events_per_day, color='r', linestyle='--', label='Average Events per Day') # Add the average line
plt.title('Distribution of Events Over Time')
plt.xlabel('Date')
plt.ylabel('Number of Events')
plt.grid(True)
plt.xticks(rotation=45) # Rotate x-axis labels for better readability
plt.legend() # Show legend
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Top 5 and bottom 5 of events frequencies

# %%
event_counts = student_df['event'].value_counts()

student_top5_events = event_counts.head(5)
student_bottom5_events = event_counts.tail(5)

# %%
student_combined_events = pd.concat([student_top5_events, student_bottom5_events])

# %%
plt.figure(figsize=(12, 6))
bars = student_combined_events.plot(kind='bar', color=['skyblue']*5 + ['salmon']*5)
plt.title('Top 5 and Bottom 5 Event by frequency (Student)')
plt.xlabel('Events')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.tight_layout()

for i, v in enumerate(student_combined_events):
    bars.text(i, v + 0.2, str(v), ha='center', va='bottom')

plt.show()

# %%
plt.figure(figsize=(12, 6))
bars = student_combined_events.plot(kind='bar', color=['skyblue']*5 + ['salmon']*5)
plt.title('Top 5 and Bottom 5 Event by frequency (Student)')
plt.xlabel('Events')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.tight_layout()

for i, v in enumerate(student_combined_events):
    bars.text(i, v + 0.2, str(v), ha='center', va='bottom')

plt.show()

# %%
# Get the top 5 events
event_counts = student_df['event'].value_counts()
student_top5_events = event_counts.head(5).index

# Filter the dataframe to include only the top 5 events
top5_df = student_df[student_df['event'].isin(student_top5_events)]

# Convert 'timecreated' to datetime if it's not already
top5_df['timecreated'] = pd.to_datetime(top5_df['timecreated'])

# Extract the date from 'timecreated'
top5_df['date'] = top5_df['timecreated'].dt.date

# Group by 'event' and 'date' and count occurrences
event_by_day = top5_df.groupby(['date', 'event']).size().unstack(fill_value=0)

# Plot the data
plt.figure(figsize=(12, 8))
for event in student_top5_events:
    plt.plot(event_by_day.index, event_by_day[event], label=event)

plt.title('Top 5 Events by Day')
plt.xlabel('Date')
plt.ylabel('Count')
plt.legend(title='Event')
plt.grid(True)
plt.show()
# Out:
# C:\Users\sadli\AppData\Local\Temp\ipykernel_4968\3445429130.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top5_df['timecreated'] = pd.to_datetime(top5_df['timecreated'])
# C:\Users\sadli\AppData\Local\Temp\ipykernel_4968\3445429130.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top5_df['date'] = top5_df['timecreated'].dt.date

# %% [markdown]
# ### Top 5 and Bottom 5 action

# %%
action_counts = student_df['action'].value_counts()

student_top5_actions = action_counts.head(5)
student_bot5_actions = action_counts.tail(5)

# %%
student_combined_actions = pd.concat([student_top5_actions, student_bot5_actions])

# %%
plt.figure(figsize=(12, 6))
bars = student_combined_actions.plot(kind='bar', color=['skyblue']*5 + ['salmon']*5)
plt.title('Actions by Frequency (Student)')
plt.xlabel('Actions')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.tight_layout()

for i, v in enumerate(student_combined_actions):
    bars.text(i, v + 0.2, str(v), ha='center', va='bottom')

plt.show()

# %% [markdown]
# ### Top 5 and Bottom 5 of Components

# %%
component_counts = student_df['component'].value_counts()

student_top5_components = component_counts.head(5)
student_bot5_components = component_counts.tail(5)

# %%
student_combined_components = pd.concat([student_top5_components, student_bot5_components])

# %%
plt.figure(figsize=(12, 6))
bars = student_combined_components.plot(kind='bar', color=['skyblue']*5 + ['salmon']*5)
plt.title('Components by Frequency (Student)')
plt.xlabel('Components')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.tight_layout()

for i, v in enumerate(student_combined_components):
    bars.text(i, v + 0.2, str(v), ha='center', va='bottom')

plt.show()

# %%
lecturer_df.to_csv('../../cleaned_dataset/Lecturer/FIK_Lecturer.csv')
student_df.to_csv('../../cleaned_dataset/Student/FIK_Student.csv')

# %%
# %reset -f
