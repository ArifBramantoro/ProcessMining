# %% [raw]
# import pandas as pd

# %% [markdown]
# ## Reading dataset and check the info

# %%
df = pd.read_csv("../../dataset/All/22232-FEB.csv")

# %%
df
# Out:
#                 id                                 eventname     component  \
# 0        820620725                 \core\event\course_viewed          core
# 1        820620937  \mod_resource\event\course_module_viewed  mod_resource
# 2        820621281                 \core\event\course_viewed          core
# 3        820622532      \mod_quiz\event\course_module_viewed      mod_quiz
# 4        820622678                 \core\event\course_viewed          core
# ...            ...                                       ...           ...
# 7473802  909575823                 \core\event\course_viewed          core
# 7473803  909575826      \mod_quiz\event\course_module_viewed      mod_quiz
# 7473804  909575829          \mod_quiz\event\attempt_reviewed      mod_quiz
# 7473805  911365224                 \core\event\course_viewed          core
# 7473806  911365244                 \core\event\course_viewed          core
#
#            action         target    objecttable   objectid crud  edulevel  \
# 0          viewed         course            NaN        NaN    r         2
# 1          viewed  course_module       resource   513330.0    r         2
# 2          viewed         course            NaN        NaN    r         2
# 3          viewed  course_module           quiz   358744.0    r         2
# 4          viewed         course            NaN        NaN    r         2
# ...           ...            ...            ...        ...  ...       ...
# 7473802    viewed         course            NaN        NaN    r         2
# 7473803    viewed  course_module           quiz   347234.0    r         2
# 7473804  reviewed        attempt  quiz_attempts  6618231.0    r         1
# 7473805    viewed         course            NaN        NaN    r         2
# 7473806    viewed         course            NaN        NaN    r         2
#
#          contextid  ...  contextinstanceid  userid  courseid  relateduserid  \
# 0          3674768  ...              30512   70577     30512            NaN
# 1          4001092  ...            3084181   70577     30512            NaN
# 2          3674768  ...              30512   70962     30512            NaN
# 3          4021531  ...            3104427   70577     30512            NaN
# 4          3674768  ...              30512   70577     30512            NaN
# ...            ...  ...                ...     ...       ...            ...
# 7473802    3903754  ...              33749   72455     33749            NaN
# 7473803    3903842  ...            2988060   72455     33749            NaN
# 7473804    3903842  ...            2988060   72455     33749        72455.0
# 7473805    3903754  ...              33749   23927     33749            NaN
# 7473806    3903754  ...              33749   23927     33749            NaN
#
#          anonymous                             other timecreated  origin  \
# 0                0                                N;  1679370018     web
# 1                0                                N;  1679370031     web
# 2                0                                N;  1679370054     web
# 3                0                                N;  1679370145     web
# 4                0                                N;  1679370156     web
# ...            ...                               ...         ...     ...
# 7473802          0                                N;  1692680009     web
# 7473803          0                                N;  1692680022     web
# 7473804          0  a:1:{s:6:"quizid";s:6:"347234";}  1692680029     web
# 7473805          0                                N;  1694743151     web
# 7473806          0                                N;  1694743183     web
#
#                      ip realuserid
# 0        202.80.215.206        NaN
# 1        202.80.215.206        NaN
# 2        139.228.116.57        NaN
# 3        202.80.215.206        NaN
# 4        202.80.215.206        NaN
# ...                 ...        ...
# 7473802    182.3.39.202        NaN
# 7473803    182.3.39.202        NaN
# 7473804    182.3.39.202        NaN
# 7473805  125.164.22.178        NaN
# 7473806    125.164.20.3        NaN
#
# [7473807 rows x 21 columns]

# %%
df.shape
# Out:
# (7473807, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7473807 entries, 0 to 7473806
# Data columns (total 21 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   id                 int64
#  1   eventname          object
#  2   component          object
#  3   action             object
#  4   target             object
#  5   objecttable        object
#  6   objectid           float64
#  7   crud               object
#  8   edulevel           int64
#  9   contextid          int64
#  10  contextlevel       int64
#  11  contextinstanceid  int64
#  12  userid             int64
#  13  courseid           int64
#  14  relateduserid      float64
#  15  anonymous          int64
#  16  other              object
#  17  timecreated        int64
#  18  origin             object
#  19  ip                 object
#  20  realuserid         float64
# dtypes: float64(3), int64(9), object(9)
# memory usage: 1.2+ GB

# %% [markdown]
# ## Count unique values in each column

# %%
for col in df.columns:
    n = len(pd.unique(df[col]))
    print("{:<20}: {:<}".format(col, n))
# Out:
# id                  : 7472953
# eventname           : 149
# component           : 33
# action              : 31
# target              : 62
# objecttable         : 47
# objectid            : 905006
# crud                : 4
# edulevel            : 3
# contextid           : 40957
# contextlevel        : 2
# contextinstanceid   : 40957
# userid              : 3876
# courseid            : 545
# relateduserid       : 3770
# anonymous           : 1
# other               : 414814
# timecreated         : 3300486
# origin              : 4
# ip                  : 71742
# realuserid          : 3

# %% [markdown]
# ## Check if there is null values

# %%
df.isnull().sum()
# Out:
# id                         0
# eventname                  0
# component                  0
# action                     0
# target                     0
# objecttable          1712737
# objectid             1712737
# crud                       0
# edulevel                   0
# contextid                  0
# contextlevel               0
# contextinstanceid          0
# userid                     0
# courseid                   0
# relateduserid        3801276
# anonymous                  0
# other                      0
# timecreated                0
# origin                     0
# ip                     35413
# realuserid           7473766
# dtype: int64

# %% [markdown]
# ## Change time from epoch to datetime

# %% [markdown]
# ### Convert the time to datetime

# %%
df['timecreated'] = pd.to_datetime(df['timecreated'], unit='s')
df
# Out:
#                 id                                 eventname     component  \
# 0        820620725                 \core\event\course_viewed          core
# 1        820620937  \mod_resource\event\course_module_viewed  mod_resource
# 2        820621281                 \core\event\course_viewed          core
# 3        820622532      \mod_quiz\event\course_module_viewed      mod_quiz
# 4        820622678                 \core\event\course_viewed          core
# ...            ...                                       ...           ...
# 7473802  909575823                 \core\event\course_viewed          core
# 7473803  909575826      \mod_quiz\event\course_module_viewed      mod_quiz
# 7473804  909575829          \mod_quiz\event\attempt_reviewed      mod_quiz
# 7473805  911365224                 \core\event\course_viewed          core
# 7473806  911365244                 \core\event\course_viewed          core
#
#            action         target    objecttable   objectid crud  edulevel  \
# 0          viewed         course            NaN        NaN    r         2
# 1          viewed  course_module       resource   513330.0    r         2
# 2          viewed         course            NaN        NaN    r         2
# 3          viewed  course_module           quiz   358744.0    r         2
# 4          viewed         course            NaN        NaN    r         2
# ...           ...            ...            ...        ...  ...       ...
# 7473802    viewed         course            NaN        NaN    r         2
# 7473803    viewed  course_module           quiz   347234.0    r         2
# 7473804  reviewed        attempt  quiz_attempts  6618231.0    r         1
# 7473805    viewed         course            NaN        NaN    r         2
# 7473806    viewed         course            NaN        NaN    r         2
#
#          contextid  ...  contextinstanceid  userid  courseid  relateduserid  \
# 0          3674768  ...              30512   70577     30512            NaN
# 1          4001092  ...            3084181   70577     30512            NaN
# 2          3674768  ...              30512   70962     30512            NaN
# 3          4021531  ...            3104427   70577     30512            NaN
# 4          3674768  ...              30512   70577     30512            NaN
# ...            ...  ...                ...     ...       ...            ...
# 7473802    3903754  ...              33749   72455     33749            NaN
# 7473803    3903842  ...            2988060   72455     33749            NaN
# 7473804    3903842  ...            2988060   72455     33749        72455.0
# 7473805    3903754  ...              33749   23927     33749            NaN
# 7473806    3903754  ...              33749   23927     33749            NaN
#
#          anonymous                             other         timecreated  \
# 0                0                                N; 2023-03-21 03:40:18
# 1                0                                N; 2023-03-21 03:40:31
# 2                0                                N; 2023-03-21 03:40:54
# 3                0                                N; 2023-03-21 03:42:25
# 4                0                                N; 2023-03-21 03:42:36
# ...            ...                               ...                 ...
# 7473802          0                                N; 2023-08-22 04:53:29
# 7473803          0                                N; 2023-08-22 04:53:42
# 7473804          0  a:1:{s:6:"quizid";s:6:"347234";} 2023-08-22 04:53:49
# 7473805          0                                N; 2023-09-15 01:59:11
# 7473806          0                                N; 2023-09-15 01:59:43
#
#         origin              ip realuserid
# 0          web  202.80.215.206        NaN
# 1          web  202.80.215.206        NaN
# 2          web  139.228.116.57        NaN
# 3          web  202.80.215.206        NaN
# 4          web  202.80.215.206        NaN
# ...        ...             ...        ...
# 7473802    web    182.3.39.202        NaN
# 7473803    web    182.3.39.202        NaN
# 7473804    web    182.3.39.202        NaN
# 7473805    web  125.164.22.178        NaN
# 7473806    web    125.164.20.3        NaN
#
# [7473807 rows x 21 columns]

# %% [markdown]
# ### Check the range of the dataset

# %%
# Find the minimum and maximum dates
min_date = df['timecreated'].min()
max_date = df['timecreated'].max()

print('Minimum date:', min_date)
print('Maximum date:', max_date)
# Out:
# Minimum date: 2023-03-21 03:07:04
# Maximum date: 2024-03-18 17:11:19

# %% [markdown]
# ## Remove uneccessary columns

# %%
df = df.drop(columns = ['objecttable', 'objectid', 'contextid', 
                         'contextlevel', 'contextinstanceid', 'relateduserid',
                         'anonymous', 'other', 'origin', 'ip', 'realuserid'])
df
# Out:
#                 id                                 eventname     component  \
# 0        820620725                 \core\event\course_viewed          core
# 1        820620937  \mod_resource\event\course_module_viewed  mod_resource
# 2        820621281                 \core\event\course_viewed          core
# 3        820622532      \mod_quiz\event\course_module_viewed      mod_quiz
# 4        820622678                 \core\event\course_viewed          core
# ...            ...                                       ...           ...
# 7473802  909575823                 \core\event\course_viewed          core
# 7473803  909575826      \mod_quiz\event\course_module_viewed      mod_quiz
# 7473804  909575829          \mod_quiz\event\attempt_reviewed      mod_quiz
# 7473805  911365224                 \core\event\course_viewed          core
# 7473806  911365244                 \core\event\course_viewed          core
#
#            action         target crud  edulevel  userid  courseid  \
# 0          viewed         course    r         2   70577     30512
# 1          viewed  course_module    r         2   70577     30512
# 2          viewed         course    r         2   70962     30512
# 3          viewed  course_module    r         2   70577     30512
# 4          viewed         course    r         2   70577     30512
# ...           ...            ...  ...       ...     ...       ...
# 7473802    viewed         course    r         2   72455     33749
# 7473803    viewed  course_module    r         2   72455     33749
# 7473804  reviewed        attempt    r         1   72455     33749
# 7473805    viewed         course    r         2   23927     33749
# 7473806    viewed         course    r         2   23927     33749
#
#                 timecreated
# 0       2023-03-21 03:40:18
# 1       2023-03-21 03:40:31
# 2       2023-03-21 03:40:54
# 3       2023-03-21 03:42:25
# 4       2023-03-21 03:42:36
# ...                     ...
# 7473802 2023-08-22 04:53:29
# 7473803 2023-08-22 04:53:42
# 7473804 2023-08-22 04:53:49
# 7473805 2023-09-15 01:59:11
# 7473806 2023-09-15 01:59:43
#
# [7473807 rows x 10 columns]

# %%
df.isnull().sum()
# Out:
# id             0
# eventname      0
# component      0
# action         0
# target         0
# crud           0
# edulevel       0
# userid         0
# courseid       0
# timecreated    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7473807 entries, 0 to 7473806
# Data columns (total 10 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   id           int64
#  1   eventname    object
#  2   component    object
#  3   action       object
#  4   target       object
#  5   crud         object
#  6   edulevel     int64
#  7   userid       int64
#  8   courseid     int64
#  9   timecreated  datetime64[ns]
# dtypes: datetime64[ns](1), int64(4), object(5)
# memory usage: 570.2+ MB

# %% [markdown]
# ## Check if there is duplicates data and remove it

# %% [markdown]
# ### Check for duplicates

# %%
duplicate_mask = df.duplicated(keep=False)

duplicate_rows = df[duplicate_mask]
duplicate_rows
# Out:
#                  id                           eventname component   action  \
# 4286526   821724957           \core\event\course_viewed      core   viewed
# 4286527   821724957           \core\event\course_viewed      core   viewed
# 4286528   821724978           \core\event\course_viewed      core   viewed
# 4286529   821724978           \core\event\course_viewed      core   viewed
# 4286530   821725603  \core\event\calendar_event_updated      core  updated
# ...             ...                                 ...       ...      ...
# 4299473   887788094       \mod_quiz\event\report_viewed  mod_quiz   viewed
# 4299474   887796884       \mod_quiz\event\report_viewed  mod_quiz   viewed
# 4299475   887796884       \mod_quiz\event\report_viewed  mod_quiz   viewed
# 6839806  1036381154           \core\event\course_viewed      core   viewed
# 6839807  1036381154           \core\event\course_viewed      core   viewed
#
#                  target crud  edulevel  userid  courseid         timecreated
# 4286526          course    r         2   24138     30547 2023-03-22 12:10:18
# 4286527          course    r         2   24138     30547 2023-03-22 12:10:18
# 4286528          course    r         2   24138     30547 2023-03-22 12:10:20
# 4286529          course    r         2   24138     30547 2023-03-22 12:10:20
# 4286530  calendar_event    u         0   24138     30547 2023-03-22 12:11:47
# ...                 ...  ...       ...     ...       ...                 ...
# 4299473          report    r         1   24138     30547 2023-06-23 13:03:31
# 4299474          report    r         1   24138     30547 2023-06-23 13:23:08
# 4299475          report    r         1   24138     30547 2023-06-23 13:23:08
# 6839806          course    r         2   82958     30230 2024-02-13 01:47:28
# 6839807          course    r         2   82958     30230 2024-02-13 01:47:28
#
# [1708 rows x 10 columns]

# %% [markdown]
# ### Drop duplicates

# %%
df.drop_duplicates()
# Out:
#                 id                                 eventname     component  \
# 0        820620725                 \core\event\course_viewed          core
# 1        820620937  \mod_resource\event\course_module_viewed  mod_resource
# 2        820621281                 \core\event\course_viewed          core
# 3        820622532      \mod_quiz\event\course_module_viewed      mod_quiz
# 4        820622678                 \core\event\course_viewed          core
# ...            ...                                       ...           ...
# 7473802  909575823                 \core\event\course_viewed          core
# 7473803  909575826      \mod_quiz\event\course_module_viewed      mod_quiz
# 7473804  909575829          \mod_quiz\event\attempt_reviewed      mod_quiz
# 7473805  911365224                 \core\event\course_viewed          core
# 7473806  911365244                 \core\event\course_viewed          core
#
#            action         target crud  edulevel  userid  courseid  \
# 0          viewed         course    r         2   70577     30512
# 1          viewed  course_module    r         2   70577     30512
# 2          viewed         course    r         2   70962     30512
# 3          viewed  course_module    r         2   70577     30512
# 4          viewed         course    r         2   70577     30512
# ...           ...            ...  ...       ...     ...       ...
# 7473802    viewed         course    r         2   72455     33749
# 7473803    viewed  course_module    r         2   72455     33749
# 7473804  reviewed        attempt    r         1   72455     33749
# 7473805    viewed         course    r         2   23927     33749
# 7473806    viewed         course    r         2   23927     33749
#
#                 timecreated
# 0       2023-03-21 03:40:18
# 1       2023-03-21 03:40:31
# 2       2023-03-21 03:40:54
# 3       2023-03-21 03:42:25
# 4       2023-03-21 03:42:36
# ...                     ...
# 7473802 2023-08-22 04:53:29
# 7473803 2023-08-22 04:53:42
# 7473804 2023-08-22 04:53:49
# 7473805 2023-09-15 01:59:11
# 7473806 2023-09-15 01:59:43
#
# [7472953 rows x 10 columns]

# %% [markdown]
# ## Shortened the event name

# %%
shortened = list(value.split('\\')[1] + "\\" +  value.split('\\')[-1] for value in df["eventname"])
# shortened
df["event"] = shortened
df
# Out:
#                 id                                 eventname     component  \
# 0        820620725                 \core\event\course_viewed          core
# 1        820620937  \mod_resource\event\course_module_viewed  mod_resource
# 2        820621281                 \core\event\course_viewed          core
# 3        820622532      \mod_quiz\event\course_module_viewed      mod_quiz
# 4        820622678                 \core\event\course_viewed          core
# ...            ...                                       ...           ...
# 7473802  909575823                 \core\event\course_viewed          core
# 7473803  909575826      \mod_quiz\event\course_module_viewed      mod_quiz
# 7473804  909575829          \mod_quiz\event\attempt_reviewed      mod_quiz
# 7473805  911365224                 \core\event\course_viewed          core
# 7473806  911365244                 \core\event\course_viewed          core
#
#            action         target crud  edulevel  userid  courseid  \
# 0          viewed         course    r         2   70577     30512
# 1          viewed  course_module    r         2   70577     30512
# 2          viewed         course    r         2   70962     30512
# 3          viewed  course_module    r         2   70577     30512
# 4          viewed         course    r         2   70577     30512
# ...           ...            ...  ...       ...     ...       ...
# 7473802    viewed         course    r         2   72455     33749
# 7473803    viewed  course_module    r         2   72455     33749
# 7473804  reviewed        attempt    r         1   72455     33749
# 7473805    viewed         course    r         2   23927     33749
# 7473806    viewed         course    r         2   23927     33749
#
#                 timecreated                              event
# 0       2023-03-21 03:40:18                 core\course_viewed
# 1       2023-03-21 03:40:31  mod_resource\course_module_viewed
# 2       2023-03-21 03:40:54                 core\course_viewed
# 3       2023-03-21 03:42:25      mod_quiz\course_module_viewed
# 4       2023-03-21 03:42:36                 core\course_viewed
# ...                     ...                                ...
# 7473802 2023-08-22 04:53:29                 core\course_viewed
# 7473803 2023-08-22 04:53:42      mod_quiz\course_module_viewed
# 7473804 2023-08-22 04:53:49          mod_quiz\attempt_reviewed
# 7473805 2023-09-15 01:59:11                 core\course_viewed
# 7473806 2023-09-15 01:59:43                 core\course_viewed
#
# [7473807 rows x 11 columns]

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ### Distribution of Events Over Time

# %%
events_by_day = df.groupby(df['timecreated'].dt.date).size()

# %%
# PLot the distribution of events over time
plt.figure(figsize=(10, 6))
events_by_day.plot(kind='line', marker='o', color='b')
plt.title('Distribution of Events Over Time')
plt.xlabel('Date')
plt.ylabel('Number of Events')
plt.grid(True)
plt.xticks(rotation=45) # Rotate x-axis labels for better readability
plt.tight_layout()
plt.show()

# %%
# Filter data between two dates
filtered_df = df.loc[(df['timecreated'] < '2023-06-26')]

# %%
filtered_events_by_day = filtered_df.groupby(filtered_df['timecreated'].dt.date).size()

# %%
# PLot the distribution of events over time
plt.figure(figsize=(10, 6))
filtered_events_by_day.plot(kind='line', marker='o', color='b')
plt.title('Distribution of Events Over Time')
plt.xlabel('Date')
plt.ylabel('Number of Events')
plt.grid(True)
plt.xticks(rotation=45) # Rotate x-axis labels for better readability
plt.tight_layout()
plt.show()

# %%
# Group events by educational level and calculate the frequency of events for each level
events_by_edulevel = filtered_df.groupby('edulevel').size()

# %%
# Plot the distribution of events across different educational levels
plt.figure(figsize=(10, 6))
events_by_edulevel.plot(kind='bar', color='salmon')
plt.title('Distribution of Events Across Educational Levels')
plt.xlabel('Educational Level')
plt.ylabel('Frequency of Events')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Admin EDA

# %%
# Select the admin data
admin_df = filtered_df[filtered_df['edulevel'] == 0]
# admin_df

# %% [markdown]
# ### Count how many unique values in each column

# %%
for col in admin_df.columns:
    n = len(pd.unique(admin_df[col]))
    print("{:<20}: {:<}".format(col, n))
# Out:
# id                  : 814684
# eventname           : 34
# component           : 7
# action              : 9
# target              : 23
# crud                : 4
# edulevel            : 1
# userid              : 3661
# courseid            : 519
# timecreated         : 619035
# event               : 34

# %% [markdown]
# ### Events over time

# %%
admin_events_by_day = admin_df.groupby(admin_df['timecreated'].dt.date).size()

# %%
# Calculate the average number of events per day
average_events_per_day = admin_events_by_day.mean()

# PLot the distribution of events over time
plt.figure(figsize=(10, 6))
admin_events_by_day.plot(kind='line', marker='o', color='b')
plt.axhline(y=average_events_per_day, color='r', linestyle='--', label='Average Events per Day') # Add the average line
plt.title('Distribution of Events Over Time')
plt.xlabel('Date')
plt.ylabel('Number of Events')
plt.grid(True)
plt.xticks(rotation=45) # Rotate x-axis labels for better readability
plt.legend() # Show legend
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Top 5 and bottom 5 of event frequencies

# %%
event_counts = admin_df['event'].value_counts()

admin_top5_events = event_counts.head(5)
admin_bottom5_events = event_counts.tail(5)

# %%
admin_combined_events = pd.concat([admin_top5_events, admin_bottom5_events])

# %%
plt.figure(figsize=(12, 6))
bars = admin_combined_events.plot(kind='bar', color=['skyblue']*5 + ['salmon']*5)
plt.title('Top 5 and Bottom 5 Events by Frequency (Admin)')
plt.xlabel('Events')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.tight_layout()

for i, v in enumerate(admin_combined_events):
    bars.text(i, v + 0.2, str(v), ha='center', va='bottom')
    
plt.show()

# %%
plt.figure(figsize=(12, 6))
bars = admin_combined_events.plot(kind='bar', color=['skyblue']*5 + ['salmon']*5)
plt.title('Top 5 and Bottom 5 Events by Frequency (Admin)')
plt.xlabel('Events')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.tight_layout()

for i, v in enumerate(admin_combined_events):
    bars.text(i, v + 0.2, str(v), ha='center', va='bottom')
    
plt.show()

# %% [markdown]
# ### Top 5 and bottom 5 action

# %%
action_counts = admin_df['action'].value_counts()

admin_top5_actions = action_counts.head(5)
admin_bot5_actions = action_counts.tail(4)

# %%
admin_combined_actions = pd.concat([admin_top5_actions, admin_bot5_actions])

# %%
plt.figure(figsize=(12, 6))
bars = admin_combined_actions.plot(kind='bar', color=['skyblue']*5 + ['salmon']*5)
plt.title('Actions by Frequency (Admin)')
plt.xlabel('Actions')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.tight_layout()

for i, v in enumerate(admin_combined_actions):
    bars.text(i, v + 0.2, str(v), ha='center', va='bottom')

plt.show()

# %% [markdown]
# ### Top 5 and bottom 5 of components

# %%
component_counts = admin_df['component'].value_counts()

admin_top5_components = component_counts.head(4)
admin_bot5_components = component_counts.tail(3)

# %%
admin_combined_components = pd.concat([admin_top5_components, admin_bot5_components])

# %%
plt.figure(figsize=(12,6))
bars = admin_combined_components.plot(kind='bar', color=['skyblue']*5 + ['salmon']*5)
plt.title('Components by Frequency (Admin)')
plt.xlabel('Components')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.tight_layout()

for i, v in enumerate(admin_combined_components):
    bars.text(i, v + 0.2, str(v), ha='center', va='bottom')

plt.show()

# %% [markdown]
# ## Lecturer EDA

# %%
# Select the lecturer data
lecturer_df = filtered_df[filtered_df['edulevel'] == 1]
# lecturer_df

# %% [markdown]
# ### Count how many unique values in each column

# %%
for col in lecturer_df.columns:
    n = len(pd.unique(lecturer_df[col]))
    print("{:<20}: {:<}".format(col, n))
# Out:
# id                  : 471985
# eventname           : 58
# component           : 14
# action              : 18
# target              : 28
# crud                : 4
# edulevel            : 1
# userid              : 3530
# courseid            : 496
# timecreated         : 331994
# event               : 58

# %% [markdown]
# ### Events over time

# %%
lecturer_events_by_day = lecturer_df.groupby(lecturer_df['timecreated'].dt.date).size()

# %%
# Calculate the average number of events per day
average_events_per_day = lecturer_events_by_day.mean()

# PLot the distribution of events over time
plt.figure(figsize=(10, 6))
lecturer_events_by_day.plot(kind='line', marker='o', color='b')
plt.axhline(y=average_events_per_day, color='r', linestyle='--', label='Average Events per Day') # Add the average line
plt.title('Distribution of Events Over Time')
plt.xlabel('Date')
plt.ylabel('Number of Events')
plt.grid(True)
plt.xticks(rotation=45) # Rotate x-axis labels for better readability
plt.legend() # Show legend
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Top 5 and bottom 5 of event frequencies

# %%
event_counts = lecturer_df['event'].value_counts()

lecturer_top5_events = event_counts.head(5)
lecturer_bottom5_events = event_counts.tail(5)

# %%
lecturer_combined_events = pd.concat([lecturer_top5_events, lecturer_bottom5_events])

# %%
plt.figure(figsize=(12, 6))
bars = lecturer_combined_events.plot(kind='bar', color=['skyblue']*5 + ['salmon']*5)
plt.title('Top 5 and Bottom 5 Events by frequency (Lecturer)')
plt.xlabel('Events')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.tight_layout()

for i, v in enumerate(lecturer_combined_events):
    bars.text(i, v + 0.2, str(v), ha='center', va='bottom')

plt.show()

# %%
plt.figure(figsize=(12, 6))
bars = lecturer_combined_events.plot(kind='bar', color=['skyblue']*5 + ['salmon']*5)
plt.title('Top 5 and Bottom 5 Events by frequency (Lecturer)')
plt.xlabel('Events')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.tight_layout()

for i, v in enumerate(lecturer_combined_events):
    bars.text(i, v + 0.2, str(v), ha='center', va='bottom')

plt.show()

# %%
# Get the top 5 events
event_counts = lecturer_df['event'].value_counts()
lecturer_top5_events = event_counts.head(5).index

# Filter the dataframe to include only the top 5 events
top5_df = lecturer_df[lecturer_df['event'].isin(lecturer_top5_events)]

# Convert 'timecreated' to datetime if it's not already
top5_df['timecreated'] = pd.to_datetime(top5_df['timecreated'])

# Extract the date from 'timecreated'
top5_df['date'] = top5_df['timecreated'].dt.date

# Group by 'event' and 'date' and count occurrences
event_by_day = top5_df.groupby(['date', 'event']).size().unstack(fill_value=0)

# Plot the data
plt.figure(figsize=(12, 8))
for event in lecturer_top5_events:
    plt.plot(event_by_day.index, event_by_day[event], label=event)

plt.title('Top 5 Events by Day')
plt.xlabel('Date')
plt.ylabel('Count')
plt.legend(title='Event')
plt.grid(True)
plt.show()
# Out:
# C:\Users\sadli\AppData\Local\Temp\ipykernel_13480\3082429642.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top5_df['timecreated'] = pd.to_datetime(top5_df['timecreated'])
# C:\Users\sadli\AppData\Local\Temp\ipykernel_13480\3082429642.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top5_df['date'] = top5_df['timecreated'].dt.date

# %% [markdown]
# ### Top 5 and bottom 5 actions

# %%
action_counts = lecturer_df['action'].value_counts()

lecturer_top5_actions = action_counts.head(5)
lecturer_bot5_actions = action_counts.tail(5)

# %%
lecturer_combined_actions = pd.concat([lecturer_top5_actions, lecturer_bot5_actions])

# %%
plt.figure(figsize=(12, 6))
bars = lecturer_combined_actions.plot(kind='bar', color=['skyblue']*5 + ['salmon']*5)
plt.title('Actions by Frequency (Lecturer)')
plt.xlabel('Actions')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.tight_layout()

for i, v in enumerate(lecturer_combined_actions):
    bars.text(i, v + 0.2, str(v), ha='center', va='bottom')

plt.show()

# %% [markdown]
# ### Top 5 and Bottom 5 components

# %%
component_counts = lecturer_df['component'].value_counts()

lecturer_top5_components = component_counts.head(5)
lecturer_bot5_components = component_counts.tail(5)

# %%
lecturer_combined_components = pd.concat([lecturer_top5_components, lecturer_bot5_components])

# %%
plt.figure(figsize=(12, 6))
bars = lecturer_combined_components.plot(kind='bar', color=['skyblue']*5 + ['salmon']*5)
plt.title('Components by Frequency (Lecturer)')
plt.xlabel('Components')
plt.ylabel('Frequency')
plt.xticks(rotation=45)

for i, v in enumerate(lecturer_combined_components):
    bars.text(i, v + 0.2, str(v), ha='center', va='bottom')

plt.show()

# %%
lecturer_df.to_csv('../../cleaned_dataset/Lecturer/FEB_Lecturer.csv')

# %% [markdown]
# ## Student EDA

# %%
# Select the student data
student_df = filtered_df[filtered_df['edulevel'] == 2]
# student_df

# %% [markdown]
# ### Check how many unique values in each column

# %%
for col in student_df.columns:
    n = len(pd.unique(student_df[col]))
    print("{:<20}: {:<}".format(col, n))
# Out:
# id                  : 6172787
# eventname           : 57
# component           : 21
# action              : 15
# target              : 22
# crud                : 4
# edulevel            : 1
# userid              : 3794
# courseid            : 544
# timecreated         : 3132710
# event               : 57

# %% [markdown]
# ### Events over time

# %%
student_events_by_day = student_df.groupby(student_df['timecreated'].dt.date).size()

# %%
# Calculate the average number of events per day
average_events_per_day = student_events_by_day.mean()

# PLot the distribution of events over time
plt.figure(figsize=(10, 6))
student_events_by_day.plot(kind='line', marker='o', color='b')
plt.axhline(y=average_events_per_day, color='r', linestyle='--', label='Average Events per Day') # Add the average line
plt.title('Distribution of Events Over Time')
plt.xlabel('Date')
plt.ylabel('Number of Events')
plt.grid(True)
plt.xticks(rotation=45) # Rotate x-axis labels for better readability
plt.legend() # Show legend
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Top 5 and bottom 5 of events frequencies

# %%
event_counts = student_df['event'].value_counts()

student_top5_events = event_counts.head(5)
student_bottom5_events = event_counts.tail(5)

# %%
student_combined_events = pd.concat([student_top5_events, student_bottom5_events])

# %%
plt.figure(figsize=(12, 6))
bars = student_combined_events.plot(kind='bar', color=['skyblue']*5 + ['salmon']*5)
plt.title('Top 5 and Bottom 5 Event by frequency (Student)')
plt.xlabel('Events')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.tight_layout()

for i, v in enumerate(student_combined_events):
    bars.text(i, v + 0.2, str(v), ha='center', va='bottom')

plt.show()

# %%
plt.figure(figsize=(12, 6))
bars = student_combined_events.plot(kind='bar', color=['skyblue']*5 + ['salmon']*5)
plt.title('Top 5 and Bottom 5 Event by frequency (Student)')
plt.xlabel('Events')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.tight_layout()

for i, v in enumerate(student_combined_events):
    bars.text(i, v + 0.2, str(v), ha='center', va='bottom')

plt.show()

# %%
# Get the top 5 events
event_counts = student_df['event'].value_counts()
student_top5_events = event_counts.head(5).index

# Filter the dataframe to include only the top 5 events
top5_df = student_df[student_df['event'].isin(student_top5_events)]

# Convert 'timecreated' to datetime if it's not already
top5_df['timecreated'] = pd.to_datetime(top5_df['timecreated'])

# Extract the date from 'timecreated'
top5_df['date'] = top5_df['timecreated'].dt.date

# Group by 'event' and 'date' and count occurrences
event_by_day = top5_df.groupby(['date', 'event']).size().unstack(fill_value=0)

# Plot the data
plt.figure(figsize=(12, 8))
for event in student_top5_events:
    plt.plot(event_by_day.index, event_by_day[event], label=event)

plt.title('Top 5 Events by Day')
plt.xlabel('Date')
plt.ylabel('Count')
plt.legend(title='Event')
plt.grid(True)
plt.show()
# Out:
# C:\Users\sadli\AppData\Local\Temp\ipykernel_13480\3445429130.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top5_df['timecreated'] = pd.to_datetime(top5_df['timecreated'])
# C:\Users\sadli\AppData\Local\Temp\ipykernel_13480\3445429130.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top5_df['date'] = top5_df['timecreated'].dt.date

# %% [markdown]
# ### Top 5 and Bottom 5 action

# %%
action_counts = student_df['action'].value_counts()

student_top5_actions = action_counts.head(5)
student_bot5_actions = action_counts.tail(5)

# %%
student_combined_actions = pd.concat([student_top5_actions, student_bot5_actions])

# %%
plt.figure(figsize=(12, 6))
bars = student_combined_actions.plot(kind='bar', color=['skyblue']*5 + ['salmon']*5)
plt.title('Actions by Frequency (Student)')
plt.xlabel('Actions')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.tight_layout()

for i, v in enumerate(student_combined_actions):
    bars.text(i, v + 0.2, str(v), ha='center', va='bottom')

plt.show()

# %% [markdown]
# ### Top 5 and Bottom 5 of Components

# %%
component_counts = student_df['component'].value_counts()

student_top5_components = component_counts.head(5)
student_bot5_components = component_counts.tail(5)

# %%
student_combined_components = pd.concat([student_top5_components, student_bot5_components])

# %%
plt.figure(figsize=(12, 6))
bars = student_combined_components.plot(kind='bar', color=['skyblue']*5 + ['salmon']*5)
plt.title('Components by Frequency (Student)')
plt.xlabel('Components')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.tight_layout()

for i, v in enumerate(student_combined_components):
    bars.text(i, v + 0.2, str(v), ha='center', va='bottom')

plt.show()

# %%
student_df.to_csv('../../cleaned_dataset/Student/FEB_Student.csv')

# %%
# %reset -f
